# %%
import numpy as np
import pandas as pd

# %%
rf_path = "./rt-ifttt/rt-ifttt.csv"
rf_data = pd.read_csv(rf_path)

# %%
rf_data
# Out:
#       Unnamed: 0  OutdoorUV  OutdoorVisibleRay_Lux  OutdoorTemperature_C  \
# 0              0       4.21           51624.113281                 30.68
# 1              1       4.20           51675.531250                 30.63
# 2              2       4.24           52035.460938                 30.76
# 3              3       4.23           51984.042969                 30.75
# 4              4       4.24           51881.207031                 30.87
# ...          ...        ...                    ...                   ...
# 9995        9995       0.73            9101.063477                 20.71
# 9996        9996       0.74            9101.063477                 20.72
# 9997        9997       0.74            9049.645508                 20.73
# 9998        9998       0.74            9101.063477                 20.73
# 9999        9999       0.74            9101.063477                 20.74
#
#       OutdoorHumidity_pct  OutdoorPressure_hPa  IndoorUV  \
# 0               27.867188              1012.76      0.07
# 1               27.899414              1012.79      0.07
# 2               27.815430              1012.74      0.05
# 3               27.781250              1012.74      0.05
# 4               27.731445              1012.70      0.05
# ...                   ...                  ...       ...
# 9995            40.255859              1013.13      0.06
# 9996            40.235352              1013.11      0.04
# 9997            40.368164              1013.15      0.03
# 9998            40.423828              1013.08      0.05
# 9999            40.425781              1013.08      0.05
#
#       IndoorVisibleRay_Lux  IndoorTemperature_C  IndoorHumidity_pct  \
# 0               925.531921                27.26           33.154297
# 1               771.276611                27.26           33.232422
# 2               668.439697                27.29           33.145508
# 3               617.021301                27.30           33.145508
# 4               617.021301                27.29           33.123047
# ...                    ...                  ...                 ...
# 9995            565.602844                27.24           30.381836
# 9996            617.021301                27.24           30.392578
# 9997            565.602844                27.24           30.381836
# 9998            565.602844                27.24           30.415039
# 9999            668.439697                27.25           30.282227
#
#       IndoorPressure_hPa
# 0                1011.81
# 1                1011.79
# 2                1011.78
# 3                1011.78
# 4                1011.72
# ...                  ...
# 9995             1012.20
# 9996             1012.15
# 9997             1012.18
# 9998             1012.18
# 9999             1012.11
#
# [10000 rows x 11 columns]

# %%
print("检查每一列是否存在空值：")
print(rf_data.isna().any())
# Out:
# 检查每一列是否存在空值：
# Unnamed: 0               False
# OutdoorUV                False
# OutdoorVisibleRay_Lux    False
# OutdoorTemperature_C     False
# OutdoorHumidity_pct      False
# OutdoorPressure_hPa      False
# IndoorUV                 False
# IndoorVisibleRay_Lux     False
# IndoorTemperature_C      False
# IndoorHumidity_pct       False
# IndoorPressure_hPa       False
# dtype: bool

# %%
weather_humidity_path = "./Historical Hourly Weather Data 2012-2017/humidity.csv"
weather_pressure_path = "./Historical Hourly Weather Data 2012-2017/pressure.csv"
weather_temperature_path = "./Historical Hourly Weather Data 2012-2017/temperature.csv"
weather_wind_speed_path = "./Historical Hourly Weather Data 2012-2017/wind_speed.csv"
weather_humidity_data = pd.read_csv(weather_humidity_path)
weather_pressure_data = pd.read_csv(weather_pressure_path)
weather_temperature_data = pd.read_csv(weather_temperature_path)
weather_wind_speed_data = pd.read_csv(weather_wind_speed_path)
weather_data = [weather_humidity_data, weather_pressure_data, weather_temperature_data, weather_wind_speed_data]

# %%
for idx, dataset in enumerate(weather_data):
    print("检查第 " + str(idx) + " 个数据集的每一列是否存在空值：")
    print(dataset.isna().any())
# Out:
# 检查第 0 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver             True
# Portland              True
# San Francisco         True
# Seattle               True
# Los Angeles           True
# San Diego             True
# Las Vegas             True
# Phoenix               True
# Albuquerque           True
# Denver                True
# San Antonio           True
# Dallas                True
# Houston               True
# Kansas City           True
# Minneapolis           True
# Saint Louis           True
# Chicago               True
# Nashville             True
# Indianapolis          True
# Atlanta               True
# Detroit               True
# Jacksonville          True
# Charlotte             True
# Miami                 True
# Pittsburgh            True
# Toronto               True
# Philadelphia          True
# New York              True
# Montreal              True
# Boston                True
# Beersheba             True
# Tel Aviv District     True
# Eilat                 True
# Haifa                 True
# Nahariyya             True
# Jerusalem             True
# dtype: bool
# 检查第 1 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver             True
# Portland              True
# San Francisco         True
# Seattle               True
# Los Angeles           True
# San Diego             True
# Las Vegas             True
# Phoenix               True
# Albuquerque           True
# Denver                True
# San Antonio           True
# Dallas                True
# Houston               True
# Kansas City           True
# Minneapolis           True
# Saint Louis           True
# Chicago               True
# Nashville             True
# Indianapolis          True
# Atlanta               True
# Detroit               True
# Jacksonville          True
# Charlotte             True
# Miami                 True
# Pittsburgh            True
# Toronto               True
# Philadelphia          True
# New York              True
# Montreal              True
# Boston                True
# Beersheba             True
# Tel Aviv District     True
# Eilat                 True
# Haifa                 True
# Nahariyya             True
# Jerusalem             True
# dtype: bool
# 检查第 2 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver             True
# Portland              True
# San Francisco         True
# Seattle               True
# Los Angeles           True
# San Diego             True
# Las Vegas             True
# Phoenix               True
# Albuquerque           True
# Denver                True
# San Antonio           True
# Dallas                True
# Houston               True
# Kansas City           True
# Minneapolis           True
# Saint Louis           True
# Chicago               True
# Nashville             True
# Indianapolis          True
# Atlanta               True
# Detroit               True
# Jacksonville          True
# Charlotte             True
# Miami                 True
# Pittsburgh            True
# Toronto               True
# Philadelphia          True
# New York              True
# Montreal              True
# Boston                True
# Beersheba             True
# Tel Aviv District     True
# Eilat                 True
# Haifa                 True
# Nahariyya             True
# Jerusalem             True
# dtype: bool
# 检查第 3 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver             True
# Portland              True
# San Francisco         True
# Seattle               True
# Los Angeles           True
# San Diego             True
# Las Vegas             True
# Phoenix               True
# Albuquerque           True
# Denver                True
# San Antonio           True
# Dallas                True
# Houston               True
# Kansas City           True
# Minneapolis           True
# Saint Louis           True
# Chicago               True
# Nashville             True
# Indianapolis          True
# Atlanta               True
# Detroit               True
# Jacksonville          True
# Charlotte             True
# Miami                 True
# Pittsburgh            True
# Toronto               True
# Philadelphia          True
# New York              True
# Montreal              True
# Boston                True
# Beersheba             True
# Tel Aviv District     True
# Eilat                 True
# Haifa                 True
# Nahariyya             True
# Jerusalem             True
# dtype: bool

# %%
for dataset in weather_data:
    for col_name in dataset.columns:
        # 处理空值
        if dataset[col_name].isnull().any():
            # 用平均值填充
            dataset.fillna({col_name: int(dataset[col_name].mean())}, inplace=True)

# %%
for idx, dataset in enumerate(weather_data):
    print("检查第 " + str(idx) + " 个数据集的每一列是否存在空值：")
    print(dataset.isna().any())
# Out:
# 检查第 0 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver            False
# Portland             False
# San Francisco        False
# Seattle              False
# Los Angeles          False
# San Diego            False
# Las Vegas            False
# Phoenix              False
# Albuquerque          False
# Denver               False
# San Antonio          False
# Dallas               False
# Houston              False
# Kansas City          False
# Minneapolis          False
# Saint Louis          False
# Chicago              False
# Nashville            False
# Indianapolis         False
# Atlanta              False
# Detroit              False
# Jacksonville         False
# Charlotte            False
# Miami                False
# Pittsburgh           False
# Toronto              False
# Philadelphia         False
# New York             False
# Montreal             False
# Boston               False
# Beersheba            False
# Tel Aviv District    False
# Eilat                False
# Haifa                False
# Nahariyya            False
# Jerusalem            False
# dtype: bool
# 检查第 1 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver            False
# Portland             False
# San Francisco        False
# Seattle              False
# Los Angeles          False
# San Diego            False
# Las Vegas            False
# Phoenix              False
# Albuquerque          False
# Denver               False
# San Antonio          False
# Dallas               False
# Houston              False
# Kansas City          False
# Minneapolis          False
# Saint Louis          False
# Chicago              False
# Nashville            False
# Indianapolis         False
# Atlanta              False
# Detroit              False
# Jacksonville         False
# Charlotte            False
# Miami                False
# Pittsburgh           False
# Toronto              False
# Philadelphia         False
# New York             False
# Montreal             False
# Boston               False
# Beersheba            False
# Tel Aviv District    False
# Eilat                False
# Haifa                False
# Nahariyya            False
# Jerusalem            False
# dtype: bool
# 检查第 2 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver            False
# Portland             False
# San Francisco        False
# Seattle              False
# Los Angeles          False
# San Diego            False
# Las Vegas            False
# Phoenix              False
# Albuquerque          False
# Denver               False
# San Antonio          False
# Dallas               False
# Houston              False
# Kansas City          False
# Minneapolis          False
# Saint Louis          False
# Chicago              False
# Nashville            False
# Indianapolis         False
# Atlanta              False
# Detroit              False
# Jacksonville         False
# Charlotte            False
# Miami                False
# Pittsburgh           False
# Toronto              False
# Philadelphia         False
# New York             False
# Montreal             False
# Boston               False
# Beersheba            False
# Tel Aviv District    False
# Eilat                False
# Haifa                False
# Nahariyya            False
# Jerusalem            False
# dtype: bool
# 检查第 3 个数据集的每一列是否存在空值：
# datetime             False
# Vancouver            False
# Portland             False
# San Francisco        False
# Seattle              False
# Los Angeles          False
# San Diego            False
# Las Vegas            False
# Phoenix              False
# Albuquerque          False
# Denver               False
# San Antonio          False
# Dallas               False
# Houston              False
# Kansas City          False
# Minneapolis          False
# Saint Louis          False
# Chicago              False
# Nashville            False
# Indianapolis         False
# Atlanta              False
# Detroit              False
# Jacksonville         False
# Charlotte            False
# Miami                False
# Pittsburgh           False
# Toronto              False
# Philadelphia         False
# New York             False
# Montreal             False
# Boston               False
# Beersheba            False
# Tel Aviv District    False
# Eilat                False
# Haifa                False
# Nahariyya            False
# Jerusalem            False
# dtype: bool

# %%
bridge_21416_DPM_path = "./2021-04-16/2021-04-16 00-DPM.csv"
bridge_21416_HPT_path = "./2021-04-16/2021-04-16 00-HPT.csv"
bridge_21416_RHS_path = "./2021-04-16/2021-04-16 00-RHS.csv"
bridge_21416_ULT_path = "./2021-04-16/2021-04-16 00-ULT.csv"
bridge_21416_VIB_path = "./2021-04-16/2021-04-16 00-VIB.csv"
bridge_21416_VIC_path = "./2021-04-16/2021-04-16 00-VIC.csv"
bridge_21416_DPM_data = pd.read_csv(bridge_21416_DPM_path)
bridge_21416_HPT_data = pd.read_csv(bridge_21416_HPT_path)
bridge_21416_RHS_data = pd.read_csv(bridge_21416_RHS_path)
bridge_21416_ULT_data = pd.read_csv(bridge_21416_ULT_path)
bridge_21416_VIB_data = pd.read_csv(bridge_21416_VIB_path)
bridge_21416_VIC_data = pd.read_csv(bridge_21416_VIC_path)

bridge_data = [bridge_21416_DPM_data, bridge_21416_HPT_data, bridge_21416_RHS_data, bridge_21416_ULT_data, bridge_21416_VIB_data,bridge_21416_VIC_data]

# %%
for idx, dataset in enumerate(bridge_data):
    print("检查第 " + str(idx) + " 个数据集的每一列是否存在空值：")
    print(dataset.isna().any())
# Out:
# 检查第 0 个数据集的每一列是否存在空值：
# 00:00:00.000    False
#  103.761        False
#  101.761        False
# Unnamed: 3       True
# dtype: bool
# 检查第 1 个数据集的每一列是否存在空值：
# 00:00:00.000    False
# 4854.628        False
# 4799.306        False
# 3366.273        False
# 3323.542        False
# 2026.681        False
# 1960.522        False
# 1204.850        False
# 1158.819        False
# 1637.626        False
# 1566.018        False
#  960.728        False
#  929.909        False
# Unnamed: 13      True
# dtype: bool
# 检查第 2 个数据集的每一列是否存在空值：
# 00:00:00.000    False
#   24.478        False
#   48.877        False
#   24.611        False
#   55.545        False
#   24.291        False
#   42.173        False
#   24.401        False
#   43.895        False
#   24.864        False
#   78.694        False
#   24.850        False
#   78.495        False
# Unnamed: 13      True
# dtype: bool
# 检查第 3 个数据集的每一列是否存在空值：
# 00:00:00.000    False
#    5.629        False
#  370.062        False
# Unnamed: 3       True
# dtype: bool
# 检查第 4 个数据集的每一列是否存在空值：
# 00:00:00.000    False
#   -0.387        False
#    0.483        False
#    0.155        False
#    0.239        False
#   -0.312        False
#    0.869        False
#   -0.280        False
#    0.495        False
#   -0.694        False
#    0.000        False
#    0.361        False
#    0.590        False
#   -0.073        False
# Unnamed: 14      True
# dtype: bool
# 检查第 5 个数据集的每一列是否存在空值：
# 00:00:00.000    False
#   -0.465        False
#    0.106        False
#   -0.033        False
#   -0.960        False
#    5.107        False
#   -0.370        False
#   -9.802        False
#    3.589        False
#    0.418        False
#    0.257        False
#   -1.799        False
#    0.587        False
# Unnamed: 13      True
# dtype: bool

# %%
for idx in range(len(weather_data)):
    weather_data[idx] = weather_data[idx].drop(weather_data[idx].columns[0], axis=1)

# %%
weather_data[0]
# Out:
#        Vancouver  Portland  San Francisco  Seattle  Los Angeles  San Diego  \
# 0           81.0      74.0           76.0     77.0         62.0       67.0
# 1           76.0      81.0           88.0     81.0         88.0       82.0
# 2           76.0      80.0           87.0     80.0         88.0       81.0
# 3           76.0      80.0           86.0     80.0         88.0       81.0
# 4           77.0      80.0           85.0     79.0         88.0       81.0
# ...          ...       ...            ...      ...          ...        ...
# 45248       81.0      81.0           76.0     93.0         24.0       72.0
# 45249       81.0      71.0           76.0     87.0         21.0       72.0
# 45250       81.0      71.0           76.0     93.0         23.0       68.0
# 45251       81.0      71.0           76.0     87.0         14.0       63.0
# 45252       81.0      76.0           76.0     75.0         56.0       72.0
#
#        Las Vegas  Phoenix  Albuquerque  Denver  ...  Philadelphia  New York  \
# 0           31.0     37.0         45.0    53.0  ...          68.0      66.0
# 1           22.0     23.0         50.0    62.0  ...          71.0      58.0
# 2           21.0     23.0         49.0    62.0  ...          70.0      57.0
# 3           21.0     23.0         49.0    62.0  ...          70.0      57.0
# 4           21.0     23.0         49.0    62.0  ...          69.0      57.0
# ...          ...      ...          ...     ...  ...           ...       ...
# 45248       18.0     68.0         37.0    18.0  ...          27.0      66.0
# 45249       18.0     73.0         34.0    12.0  ...          29.0      66.0
# 45250       17.0     60.0         32.0    15.0  ...          31.0      66.0
# 45251       17.0     33.0         30.0    28.0  ...          26.0      66.0
# 45252       17.0     23.0         34.0    31.0  ...          32.0      66.0
#
#        Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 0          71.0    77.0       70.0               66.0   25.0   79.0
# 1          93.0    68.0       50.0               63.0   22.0   51.0
# 2          91.0    68.0       51.0               62.0   22.0   51.0
# 3          87.0    68.0       51.0               62.0   22.0   51.0
# 4          84.0    68.0       52.0               62.0   22.0   51.0
# ...         ...     ...        ...                ...    ...    ...
# 45248      64.0    37.0       70.0               66.0   53.0   79.0
# 45249      59.0    74.0       70.0               66.0   53.0   79.0
# 45250      66.0    74.0       70.0               66.0   53.0   79.0
# 45251      58.0    56.0       70.0               66.0   53.0   79.0
# 45252      58.0    56.0       70.0               66.0   53.0   79.0
#
#        Nahariyya  Jerusalem
# 0           78.0       68.0
# 1           51.0       50.0
# 2           51.0       50.0
# 3           51.0       50.0
# 4           51.0       50.0
# ...          ...        ...
# 45248       78.0       68.0
# 45249       78.0       68.0
# 45250       78.0       68.0
# 45251       78.0       68.0
# 45252       78.0       68.0
#
# [45253 rows x 36 columns]

# %%
weather_data_list = ["_humidity", "_pressure", "_temperature", "_wind_speed"]
for idx_dataset in range(len(weather_data)):   
    for idx in range(len(weather_data[idx_dataset].columns)):
        weather_data[idx_dataset].columns.values[idx] += weather_data_list[idx_dataset]

# %%
data_aggregated = pd.concat([rf_data], axis=1)
data_aggregated.columns.values[0] = "Timestamp"

# %%
data_aggregated
# Out:
#       Timestamp  OutdoorUV  OutdoorVisibleRay_Lux  OutdoorTemperature_C  \
# 0             0       4.21           51624.113281                 30.68
# 1             1       4.20           51675.531250                 30.63
# 2             2       4.24           52035.460938                 30.76
# 3             3       4.23           51984.042969                 30.75
# 4             4       4.24           51881.207031                 30.87
# ...         ...        ...                    ...                   ...
# 9995       9995       0.73            9101.063477                 20.71
# 9996       9996       0.74            9101.063477                 20.72
# 9997       9997       0.74            9049.645508                 20.73
# 9998       9998       0.74            9101.063477                 20.73
# 9999       9999       0.74            9101.063477                 20.74
#
#       OutdoorHumidity_pct  OutdoorPressure_hPa  IndoorUV  \
# 0               27.867188              1012.76      0.07
# 1               27.899414              1012.79      0.07
# 2               27.815430              1012.74      0.05
# 3               27.781250              1012.74      0.05
# 4               27.731445              1012.70      0.05
# ...                   ...                  ...       ...
# 9995            40.255859              1013.13      0.06
# 9996            40.235352              1013.11      0.04
# 9997            40.368164              1013.15      0.03
# 9998            40.423828              1013.08      0.05
# 9999            40.425781              1013.08      0.05
#
#       IndoorVisibleRay_Lux  IndoorTemperature_C  IndoorHumidity_pct  \
# 0               925.531921                27.26           33.154297
# 1               771.276611                27.26           33.232422
# 2               668.439697                27.29           33.145508
# 3               617.021301                27.30           33.145508
# 4               617.021301                27.29           33.123047
# ...                    ...                  ...                 ...
# 9995            565.602844                27.24           30.381836
# 9996            617.021301                27.24           30.392578
# 9997            565.602844                27.24           30.381836
# 9998            565.602844                27.24           30.415039
# 9999            668.439697                27.25           30.282227
#
#       IndoorPressure_hPa
# 0                1011.81
# 1                1011.79
# 2                1011.78
# 3                1011.78
# 4                1011.72
# ...                  ...
# 9995             1012.20
# 9996             1012.15
# 9997             1012.18
# 9998             1012.18
# 9999             1012.11
#
# [10000 rows x 11 columns]

# %%
for idx in range(len(weather_data)):
    data_aggregated = pd.concat([data_aggregated, weather_data[idx].head(10000)], axis=1)

# %%
data_aggregated
# Out:
#       Timestamp  OutdoorUV  OutdoorVisibleRay_Lux  OutdoorTemperature_C  \
# 0             0       4.21           51624.113281                 30.68
# 1             1       4.20           51675.531250                 30.63
# 2             2       4.24           52035.460938                 30.76
# 3             3       4.23           51984.042969                 30.75
# 4             4       4.24           51881.207031                 30.87
# ...         ...        ...                    ...                   ...
# 9995       9995       0.73            9101.063477                 20.71
# 9996       9996       0.74            9101.063477                 20.72
# 9997       9997       0.74            9049.645508                 20.73
# 9998       9998       0.74            9101.063477                 20.73
# 9999       9999       0.74            9101.063477                 20.74
#
#       OutdoorHumidity_pct  OutdoorPressure_hPa  IndoorUV  \
# 0               27.867188              1012.76      0.07
# 1               27.899414              1012.79      0.07
# 2               27.815430              1012.74      0.05
# 3               27.781250              1012.74      0.05
# 4               27.731445              1012.70      0.05
# ...                   ...                  ...       ...
# 9995            40.255859              1013.13      0.06
# 9996            40.235352              1013.11      0.04
# 9997            40.368164              1013.15      0.03
# 9998            40.423828              1013.08      0.05
# 9999            40.425781              1013.08      0.05
#
#       IndoorVisibleRay_Lux  IndoorTemperature_C  IndoorHumidity_pct  ...  \
# 0               925.531921                27.26           33.154297  ...
# 1               771.276611                27.26           33.232422  ...
# 2               668.439697                27.29           33.145508  ...
# 3               617.021301                27.30           33.145508  ...
# 4               617.021301                27.29           33.123047  ...
# ...                    ...                  ...                 ...  ...
# 9995            565.602844                27.24           30.381836  ...
# 9996            617.021301                27.24           30.392578  ...
# 9997            565.602844                27.24           30.381836  ...
# 9998            565.602844                27.24           30.415039  ...
# 9999            668.439697                27.25           30.282227  ...
#
#       Philadelphia_wind_speed  New York_wind_speed  Montreal_wind_speed  \
# 0                         2.0                  3.0                  3.0
# 1                         4.0                  7.0                  4.0
# 2                         4.0                  7.0                  4.0
# 3                         3.0                  7.0                  4.0
# 4                         3.0                  7.0                  4.0
# ...                       ...                  ...                  ...
# 9995                      3.0                  3.0                  2.0
# 9996                      3.0                  3.0                  2.0
# 9997                      3.0                  3.0                  1.0
# 9998                      3.0                  3.0                  1.0
# 9999                      3.0                  3.0                  6.0
#
#       Boston_wind_speed  Beersheba_wind_speed  Tel Aviv District_wind_speed  \
# 0                   3.0                   1.0                           2.0
# 1                   3.0                   1.0                           0.0
# 2                   3.0                   3.0                           0.0
# 3                   3.0                   3.0                           0.0
# 4                   3.0                   3.0                           0.0
# ...                 ...                   ...                           ...
# 9995                1.0                   1.0                           0.0
# 9996                2.0                   1.0                           1.0
# 9997                2.0                   1.0                           1.0
# 9998                2.0                   1.0                           1.0
# 9999                2.0                   1.0                           3.0
#
#       Eilat_wind_speed  Haifa_wind_speed  Nahariyya_wind_speed  \
# 0                  8.0               3.0                   3.0
# 1                  8.0               2.0                   2.0
# 2                  8.0               2.0                   2.0
# 3                  8.0               2.0                   2.0
# 4                  8.0               2.0                   2.0
# ...                ...               ...                   ...
# 9995               1.0               2.0                   3.0
# 9996               1.0               2.0                   3.0
# 9997               1.0               2.0                   3.0
# 9998               1.0               2.0                   3.0
# 9999               3.0               2.0                   3.0
#
#       Jerusalem_wind_speed
# 0                      1.0
# 1                      2.0
# 2                      2.0
# 3                      2.0
# 4                      2.0
# ...                    ...
# 9995                   1.0
# 9996                   1.0
# 9997                   1.0
# 9998                   1.0
# 9999                   1.0
#
# [10000 rows x 155 columns]

# %%
data_aggregated.shape[0]
# Out:
# 10000

# %%
# 模拟存储节点
# 每个store_node 包含3个信息，distance|storage space|reputation, 并计算得到一个score
store_node_num = 50
store_node = {i: {'distance': 0, 'storage space': 0, 'probability': 0, 'score_sp': 0, 'score_sd': 0, 'batches': []} for i in range(1, store_node_num + 1)}

mean, std_dev = 4000, 2200  # 均值, 标准差
gaussian_distances = np.random.normal(mean, std_dev, store_node_num)  # 生成 distance
mean, std_dev = 1000, 160  # 均值, 标准差
gaussian_storage_spaces = np.random.normal(mean, std_dev, store_node_num)  # 生成 storage_spaces
mean, std_dev = 0.6, 0.1  # 均值, 标准差
gaussian_probability = np.random.normal(mean, std_dev, store_node_num)  # 生成 storage_spaces
gaussian_probability = np.clip(gaussian_probability, 0, 1)

alpha_probability = 1000
alpha_distance = 10
# 循环遍历每个节点，为其设置高斯分布的距离
for key, node in store_node.items():
    node['distance'] = gaussian_distances[key - 1]
    node['storage space'] = gaussian_storage_spaces[key - 1]
    node['probability'] = gaussian_probability[key - 1]
    # node['score_sp'] = node['storage space'] + alpha_probability * node['probability']
    node['score_sp'] = alpha_probability * node['probability']
    # node['score_sd'] = node['storage space'] - alpha_distance * node['distance']
    node['score_sd'] = node['distance']

# gaussian_distances[gaussian_distances < 200] = 300
# gaussian_distances.min()
# gaussian_distances.max()
# x = np.sort(gaussian_probability)[::-1]
# print(x)

# %% [markdown]
# # Batch
# - Experiment Settings:
#     - 上链时间：20s
#     - Device数量：20个
# - Basic Method
#     - 数据集所有设备按照10s为上链时间，构建 basic unit，每个 unit 包含10个data point
#     - 每10s内共有 10 * device_number 个数据点，全部存储list中并shuffle再以10为单位重组为 device_number 个 unit
#     - 将这10s内的所有 unit 放入 list 并 shuffle ，再以 10 个 unit 为单位重组为 多个 Batch
# - Proposed Method
#     - 数据集所有设备按照10s为上链时间，构建 basic unit，每个 unit 包含某个特定设备的10个data point （保证 unit 中的数据全部属于同个device）
#     - 构建Batch
#         - 首先根据Device数量构建一张Graph，节点数为Device number
#             - 对权重进行初始化（初始化算法：根据0-10s这批数据生成的Query进行初始化，若使用Device编码初始化非常不合理，对后续数据影响大）
#             - 生成这10s内数据的Query
#                 - 生成方式：按照高斯分布生成，第一批数据的query用于更新构建第二批数据Batch时的Device图
#                 - 生成数量：200个数据，20个query
#                 - 每10s内的数据生成的Query应该服从同样的分布（这个必须保证且非常重要！！！ 生成时要符合高斯分布）

# %% [markdown]
# # EXP Settings

# %%
import random
import copy
device_value_max = 20
time_on_chain = 20

# 遍历各种 unit_num与 batch_num 组合得到各组实验数据
 # 每个 unit  包含的 元素 数量
# 每个 batch 包含的 unit 数量
# (unit_num, batch_num)
unit_batch_num_list = [(1, 1), (5, 2), (5, 4), (5, 5), (5, 8), (5, 10), (5, 16), (5, 20)]
unit_num, batch_num = unit_batch_num_list[1][0], unit_batch_num_list[1][1]

# %% [markdown]
# # Basic Method

# %%
batched_basic_method = {} # 以字典存储所有的Batch batch_id : []
cnt = 0
time_max = 2999
for start_time in range(0, time_max, time_on_chain):
    end_time = start_time + time_on_chain
    batch_list = []
    for time in range(start_time, end_time):
        for device in range(1, device_value_max + 1):
            # data_points.append(data_aggregated.loc[time][device])
            batch_list.append([[(time, device)]])                # 400 个数据点
    random.shuffle(batch_list) # 随机打乱
    
    for batch in batch_list:
        batched_basic_method[str(cnt)] = batch
        cnt += 1

# %%
len(batched_basic_method.items())
# batched_basic_method
# Out:
# 60000

# %% [markdown]
# # Proposed Method

# %%
# 建图
import networkx as nx
# 创建一个空的无向图
G = nx.Graph()
G.add_nodes_from(range(device_value_max))
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
# Out:
# Number of nodes: 20
# Number of edges: 0

# %%
vDevice = 1
count = 0
for node in G.nodes():
    # 为每个节点添加两个属性值
    nx.set_node_attributes(G, {node: {'device_id': vDevice}})
    count += 1
    if vDevice <= device_value_max:
            vDevice += 1

# %%
import numpy as np
from scipy.stats import truncnorm

# 定义截断正态分布
def truncated_normal(mean, std_dev, low, high):
    std_dev = max(std_dev, 1e-6)  # 避免标准差为零
    a = (low - mean) / std_dev
    b = (high - mean) / std_dev
    return truncnorm(a, b, loc=mean, scale=std_dev)

def generateQuery(num_queries, time_low, time_high, device_value_max, batch_size):
    device_low, device_high = 1, device_value_max
    query_time_length_mu = ((1 + time_on_chain) / 6) # 尽可能让 time_length 较长  on_chain: 20  (21 / 6) = 3 
    query_time_length_sigma = max(int((time_on_chain - 1) / 6), 1e-6)

    queries = []
    def is_overlap_points_less_enough(time_lower_bound, time_upper_bound, device_lower_bound, device_upper_bound, queries, min_points):
        for (q_t_l, q_t_u), (q_d_l, q_d_u) in queries:
            if time_lower_bound >= q_t_u or time_upper_bound <= q_t_l or device_upper_bound <= q_d_l or device_lower_bound >= q_d_u:
                continue
            else:
                time_delta = min(abs(time_upper_bound - q_t_l), abs(time_upper_bound - time_lower_bound), abs(time_lower_bound - q_t_u), abs(q_t_l - q_t_u))
                device_delta = min(abs(device_upper_bound - q_d_l), abs(device_upper_bound - q_d_u), abs(device_upper_bound - device_lower_bound), abs(q_d_l - q_d_u))
                if (time_delta + 1) * (device_delta + 1) > min_points:
                    return False
        return True
    
    for _ in range(num_queries):
        bounds = []
        while(True):
            tried = 0
            
            # 生成query的时间范围
            mean = (time_low + time_high) / 2  # time_low 与 time_high 相差 time_on_chain, 
            std_dev = max((time_high - time_low) / 6, 1e-6)  # 避免标准差为零, 经验法则：99.7%的数据在3个标准差内
            # 生成time_center
            time_center = round(truncated_normal(mean, std_dev, time_low, time_high).rvs())
            # print(f"time_center: {time_center}")
            time_length = abs(np.random.normal(query_time_length_mu, query_time_length_sigma))
            # print(f"time_length: {time_length}")
            time_lower_bound = round(max(time_low, time_center - time_length / 2))
            time_upper_bound = round(min(time_high, time_center + time_length / 2))
            
            # 生成查询的Device范围
            mean = (device_low + device_high) / 2
            std_dev = max((device_high - device_low) / 6, 1e-6)  # 避免标准差为零 经验法则：99.7%的数据在3个标准差内
            # 生成time_center
            device_center = round(truncated_normal(mean, std_dev, device_low, device_high).rvs())
            # device_length = abs(np.random.normal(query_device_length_mu, query_device_length_sigma))
            device_length = round( unit_num * batch_num / time_length )    # 尽可能使得 query 内的 数据点数刚好为 1
            device_lower_bound = round(max(device_low, device_center - device_length / 2))
            device_upper_bound = round(min(device_high, device_center + device_length / 2))
            
            # 计算数据点个数
            area = (time_upper_bound - time_lower_bound + 1) * (device_upper_bound - device_lower_bound + 1)
            tried += 1
            # 一批数据的总数据点个数为400个, 共16个batch，得到每个batch中有25个数据点
            # 如果生成query做到对数据点全覆盖，会导致2种batch方式最终都要访问所有的batch，时间开销上差距不大，故生成16 / 2 = 8个数据点比较合适
            # 但是query也不能太少，因为query太少会导致很多节点没有出现在对图的权重进行迭代的过程中
            if 1 <= area <= batch_size + 5 and is_overlap_points_less_enough(time_lower_bound, time_upper_bound, device_lower_bound, device_upper_bound, queries, int(batch_size / 10)):
                bounds = [(time_lower_bound, time_upper_bound), (device_lower_bound, device_upper_bound)]
                break
            if tried == 20:
                print(f"try {tried} times.")
        queries.append(bounds)
    return queries

def genQueryForBatch1(num_queries, time_low, time_high, device_value_max):
    queries = []
    for _ in range(num_queries):
        time_num = random.randint(time_low, time_high)
        device_num = random.randint(1, device_value_max)
        bounds = [(time_num, time_num), (device_num, device_num)]
        queries.append(bounds)
    return queries

# %% [markdown]
# # Device图初始化操作

# %%
import math
def init_edge_weights(G):
    count = 0
    zero_count = 0
    # 必须加上data=True才可以迭代
    for u, u_attrs in G.nodes(data=True):
        for v, v_attrs in G.nodes(data=True):
            if u != v:
                weight = 1 / (math.sqrt((u_attrs['device_id'] - v_attrs['device_id']) ** 2))
                # 添加边到图中，并附带权重信息
                G.add_edge(u, v, weight=weight)
                count += 1
    print(count)
    print(zero_count)
    print("Number of nodes:", G.number_of_nodes())
    print("Number of edges:", G.number_of_edges())

# %%
init_edge_weights(G)
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())

'''
for u, v, attrs in G.edges(data=True):
    print("Edge:", u, "-", v, ", Weight:", attrs['weight'])
'''
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
nx.draw(G, node_size=5)
plt.title("Visualization of the Graph with Nodes")
plt.show()
# Out:
# 380
# 0
# Number of nodes: 20
# Number of edges: 190
# Number of nodes: 20
# Number of edges: 190

# %% [markdown]
# # 每10s进行一次迭代，循环迭代得到最终结果
# ## 注意点：此处需要额外设置新的weight更新策略

# %%
from sklearn.cluster import KMeans
from collections import Counter
import time as time_module

def calLaplacianMatrix(adjacentMatrix):
    # compute the Degree Matrix: D=sum(A)
    degreeMatrix = np.sum(adjacentMatrix, axis=1)
    # compute the Laplacian Matrix: L=D-A
    laplacianMatrix = np.diag(degreeMatrix) - adjacentMatrix
    # print laplacianMatrix
    # normalize
    # D^(-1/2) L D^(-1/2)
    sqrtDegreeMatrix = np.diag(1.0 / (degreeMatrix ** (0.5)))
    return np.dot(np.dot(sqrtDegreeMatrix, laplacianMatrix), sqrtDegreeMatrix)

batched_proposed_method = {} # 以字典存储所有的Batch batch_id : []
cnt = 0

# %%
# 采样记录所有的Query
Query_sets = []
for start_time in range(0, time_max, time_on_chain):
    end_time = start_time + time_on_chain
    units_list = []
    unit_tmp = []
    device_id = 1
    while device_id <= device_value_max:
        time_cnt = 0
        for time in range(start_time, end_time):
            # data_points.append(data_aggregated.loc[time][device])
            unit_tmp.append((time, device_id))
            time_cnt += 1
            if time_cnt % unit_num == 0:
                units_list.append((device_id, copy.deepcopy(unit_tmp)))
                unit_tmp.clear()
        device_id += 1

    num_queries = 10
    # num_queries = int(time_on_chain * device_value_max / unit_num / batch_num / 2) # 16 / 2
    # 本次生成的Query用于更新下一次的Device
    if unit_num * batch_num == 1:
        query_set = genQueryForBatch1(num_queries, start_time, end_time - 1, device_value_max)
    else:
        query_set = generateQuery(num_queries, start_time, end_time - 1, device_value_max, unit_num * batch_num)
    Query_sets.append(copy.deepcopy(query_set)) # 将每段on_chain时间内生成的query_set整合到循环外部一个总的Query集合中
    
    # 更新Device, 从第二批数据开始，按照query更新
    batch_list = []
    for (device_id, unit) in units_list:
        batch_list.append(copy.deepcopy(unit))

    for batch in batch_list:
        batched_proposed_method[str(cnt)] = batch
        cnt += 1

# %%
batched_basic_method
# Out:
# {'0': [[(16, 15)]],
#  '1': [[(3, 11)]],
#  '2': [[(19, 1)]],
#  '3': [[(6, 13)]],
#  '4': [[(18, 14)]],
#  '5': [[(16, 4)]],
#  '6': [[(13, 7)]],
#  '7': [[(14, 10)]],
#  '8': [[(18, 20)]],
#  '9': [[(2, 14)]],
#  '10': [[(8, 6)]],
#  '11': [[(13, 4)]],
#  '12': [[(14, 6)]],
#  '13': [[(12, 16)]],
 1), (251, 1), (252, 1), (253, 1), (254, 1)],
#  '963': [(255, 1), (256, 1), (257, 1), (258, 1), (259, 1)],
#  '964': [(240, 2), (241, 2), (242, 2), (243, 2), (244, 2)],
#  '965': [(245, 2), (246, 2), (247, 2), (248, 2), (249, 2)],
#  '966': [(250, 2), (251, 2), (252, 2), (253, 2), (254, 2)],
#  '967': [(255, 2), (256, 2), (257, 2), (258, 2), (259, 2)],
#  '968': [(240, 3), (241, 3), (242, 3), (243, 3), (244, 3)],
#  '969': [(245, 3), (246, 3), (247, 3), (248, 3), (249, 3)],
#  '970': [(250, 3), (251, 3), (252, 3), (253, 3), (254, 3)],
#  '971': [(255, 3), (256, 3), (257, 3), (258, 3), (259, 3)],
#  '972': [(240, 4), (241, 4), (242, 4), (243, 4), (244, 4)],
#  '973': [(245, 4), (246, 4), (247, 4), (248, 4), (249, 4)],
#  '974': [(250, 4), (251, 4), (252, 4), (253, 4), (254, 4)],
#  '975': [(255, 4), (256, 4), (257, 4), (258, 4), (259, 4)],
#  '976': [(240, 5), (241, 5), (242, 5), (243, 5), (244, 5)],
#  '977': [(245, 5), (246, 5), (247, 5), (248, 5), (249, 5)],
#  '978': [(250, 5), (251, 5), (252, 5), (253, 5), (254, 5)],
#  '979': [(255, 5), (256, 5), (257, 5), (258, 5), (259, 5)],
#  '980': [(240, 6), (241, 6), (242, 6), (243, 6), (244, 6)],
#  '981': [(245, 6), (246, 6), (247, 6), (248, 6), (249, 6)],
#  '982': [(250, 6), (251, 6), (252, 6), (253, 6), (254, 6)],
#  '983': [(255, 6), (256, 6), (257, 6), (258, 6), (259, 6)],
#  '984': [(240, 7), (241, 7), (242, 7), (243, 7), (244, 7)],
#  '985': [(245, 7), (246, 7), (247, 7), (248, 7), (249, 7)],
#  '986': [(250, 7), (251, 7), (252, 7), (253, 7), (254, 7)],
#  '987': [(255, 7), (256, 7), (257, 7), (258, 7), (259, 7)],
#  '988': [(240, 8), (241, 8), (242, 8), (243, 8), (244, 8)],
#  '989': [(245, 8), (246, 8), (247, 8), (248, 8), (249, 8)],
#  '990': [(250, 8), (251, 8), (252, 8), (253, 8), (254, 8)],
#  '991': [(255, 8), (256, 8), (257, 8), (258, 8), (259, 8)],
#  '992': [(240, 9), (241, 9), (242, 9), (243, 9), (244, 9)],
#  '993': [(245, 9), (246, 9), (247, 9), (248, 9), (249, 9)],
#  '994': [(250, 9), (251, 9), (252, 9), (253, 9), (254, 9)],
#  '995': [(255, 9), (256, 9), (257, 9), (258, 9), (259, 9)],
#  '996': [(240, 10), (241, 10), (242, 10), (243, 10), (244, 10)],
#  '997': [(245, 10), (246, 10), (247, 10), (248, 10), (249, 10)],
#  '998': [(250, 10), (251, 10), (252, 10), (253, 10), (254, 10)],
#  '999': [(255, 10), (256, 10), (257, 10), (258, 10), (259, 10)],
#  ...}

# %% [markdown]
# ###  对 Batch 进行遍历，找到与 Q 中元素匹配的 data point，再根据 Batch 确定 Store node
# ### 测试指标：
# - 对于最后得到的所有 Store node，先按照 Probability 以转轮盘算法判断其是否正常提供数据存取服务
# - 指标一：无服务的次数
# - 指标二：提供服务的总时延

# %%
def cal_time(found_node, store_node):
    time4one_query = []
    refuse_cnt = 0
    accept_cnt = 0
    time_consumed_all = 0 # 最终该query消耗的总计时间
    for query in found_node:
        query_nodup = list(set(query))
        for node in query_nodup:
            flag = False
            for node_id, node_info in store_node.items():
                if flag:
                    break
                if node == node_id:
                    flag = True
                    # 首先获取当前节点的概率值， 判断是否能够命中
                    get_pro = node_info['probability']
                    if probabilistic_true(get_pro):
                        # 命中，计算时间开销
                        time_consumed = node_info['distance'] * 0.010756
                        #print(time_consumed)
                        time4one_query.append(time_consumed)
                        accept_cnt += 1
                    else:
                        # 未命中，记一次无服务次数
                        refuse_cnt += 1
        time_consumed_max = 0 # 最终该query消耗的总计时间
        for time_consumed in time4one_query:
            if time_consumed > time_consumed_max:
                time_consumed_max = time_consumed
        time4one_query.clear()
        time_consumed_all += time_consumed_max
    serve_prob = accept_cnt / (accept_cnt + refuse_cnt)
    time_consumed_all = time_consumed_all * (1 + serve_prob)
    return time_consumed_all, refuse_cnt, accept_cnt, serve_prob

def probabilistic_true(probability):
    return random.random() < probability

# %% [markdown]
# # 方法一：有信誉有距离

# %%
# 根据Score 排序得到 Rank，Rank自上而下遍历，直至storage node能够成功提供PoA
store_node_method_r_d = copy.deepcopy(store_node)
# 查询集存在于 Query_sets 中

# %% [markdown]
# ##### 对 数据进行查询，查询来源于 此前在每个 on_chain 时间段内生成的所有 Query
# ##### Query 中访问的是 (time, device), Batch中结构为 [unit:[(time, device), (), ..., ()], [], ..., []]

# %%
# batched_basic_method 
store_node_method_r_d_batched_basic_method = copy.deepcopy(store_node_method_r_d)

for key, batch in batched_basic_method.items():
    # 要选取一个store node存储
    sorted_nodes_r_d = sorted(store_node_method_r_d_batched_basic_method.items(), key=lambda x: x[1]['score_sd'], reverse=False)
    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes_r_d = sorted_nodes_r_d[:10]

    saved_flag = False
    for node in top_ten_nodes_r_d:
        if saved_flag:
            break
        get_pro = node[1]['probability']
        # 得到命中概率
        if probabilistic_true(get_pro):
            # 若命中，则存入
            store_node_method_r_d_batched_basic_method[node[0]]['batches'].append((key, batch))
            saved_flag = True
    if not saved_flag:
        # 10 个都没命中，则存入 rank 第一的 node 中
        store_node_method_r_d_batched_basic_method[top_ten_nodes_r_d[0][0]]['batches'].append((key, batch))

# %%
# batched_proposed_method
store_node_method_r_d_batched_proposed_method = copy.deepcopy(store_node_method_r_d)

for key, batch in batched_proposed_method.items():
    # 要选取一个store node存储
    sorted_nodes = sorted(store_node_method_r_d_batched_proposed_method.items(), key=lambda x: x[1]['score_sd'], reverse=False)  # 考虑 Distance 升序，距离小的优先
    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes = sorted_nodes[:10]
    saved_flag = False
    for node in top_ten_nodes:
        if saved_flag:
            break
        get_pro = node[1]['probability']
        # 得到命中概率
        if probabilistic_true(get_pro):
            # 若命中，则存入
            store_node_method_r_d_batched_proposed_method[node[0]]['batches'].append((key, batch)) # 考虑 reputation
            saved_flag = True
    if not saved_flag:
        # 10 个都没命中，则存入 rank 第一的 node 中
        store_node_method_r_d_batched_proposed_method[top_ten_nodes[0][0]]['batches'].append((key, batch))

# %%
print(f"length:\nQuery_sets: {len(Query_sets)}\nQuery_sets[0]: {len(Query_sets[0])}")
# Out:
# length:
# Query_sets: 150
# Query_sets[0]: 10

# %%
print(Query_sets[0])
# Out:
# [[(13, 13), (20, 20)], [(9, 9), (14, 14)], [(9, 9), (19, 19)], [(8, 8), (8, 8)], [(14, 14), (19, 19)], [(0, 0), (2, 2)], [(19, 19), (6, 6)], [(19, 19), (17, 17)], [(15, 15), (6, 6)], [(17, 17), (15, 15)]]

# %%
# 遍历Query_sets，在两种store node的存储方式上，访问所有的query，计算得到指标
found_in_basic_batch = [] # [[], [], ..., []] 记录了每个 query 中每个 point 所在的batch_id ， 用于后续去 store
found_in_proposed_batch = []
for query_set in Query_sets:
    basic_batches4q = []
    proposed_batches4q = []
    for query in query_set:
        # 对每一个 q, 得到 time 和 device 
        time_low, time_high, device_low, device_high = query[0][0], query[0][1], query[1][0], query[1][1]
        print(f"time_low:{time_low}, time_high:{time_high}, device_low:{device_low}, device_high:{device_high}")
        # 找到 device 所在的 batch, 计算出每个 q 需要访问哪些 batch
        # 直接遍历搜索空间过大，进行优化: 从time来确定Batch_id范围: 0~19s 内的数据处于 0~3 的 batch 之间
        # 由于 同一批Query_set中的元素都在同一批Batch中，故直接由time_low定出 batch range
        batch_low, batch_high = int(time_low / time_on_chain) * int(time_on_chain * device_value_max / unit_num / batch_num), (int(time_low / time_on_chain) + 1) * int(time_on_chain * device_value_max / unit_num / batch_num) - 1
        # print(f"batch_low:{batch_low} and batch_high:{batch_high}")
        for device in range(device_low, device_high + 1):
            for time in range(time_low, time_high + 1):
                # print(f"time: {time}, device: {device}")
                basic_flag = False
                proposed_flag = False
                # 对每个 （time, device） 找到所属的Batch
                for batch_id in range(batch_low, batch_high + 1):
                    # print(f"batch id is : {batch}")
                    # batch结构: [[], [], ..., []]
                    if not basic_flag:
                        batch = copy.deepcopy(batched_basic_method[str(batch_id)])
                        for unit in batch:
                            for point in unit:
                                if time == point[0] and device == point[1]:
                                    # print(f"----basic find point")
                                    # 找到了所属的Batch，继续寻找所属的store node
                                    basic_batches4q.append(batch_id)
                                    basic_flag = True
                                
                    if not proposed_flag:
                        batch = copy.deepcopy(batched_proposed_method[str(batch_id)])
                        for unit in batch:

                            if time == unit[0] and device == unit[1]:
                                # print(f"----proposed find point")
                                # 找到了所属的Batch，继续寻找所属的store node
                                proposed_batches4q.append(batch_id)
                                proposed_flag = True
                    if proposed_flag and basic_flag:
                        break
                # print(f"belong_to_basic_batch:{belong_to_basic_batch} and belong_to_proposed_batch:{belong_to_proposed_batch}")
        found_in_basic_batch.append(copy.deepcopy(basic_batches4q))
        found_in_proposed_batch.append(copy.deepcopy(proposed_batches4q))
        basic_batches4q.clear()
        proposed_batches4q.clear()
# Out:
# time_low:13, time_high:13, device_low:20, device_high:20
# time_low:9, time_high:9, device_low:14, device_high:14
# time_low:9, time_high:9, device_low:19, device_high:19
# time_low:8, time_high:8, device_low:8, device_high:8
# time_low:14, time_high:14, device_low:19, device_high:19
# time_low:0, time_high:0, device_low:2, device_high:2
# time_low:19, time_high:19, device_low:6, device_high:6
# time_low:19, time_high:19, device_low:17, device_high:17
# time_low:15, time_high:15, device_low:6, device_high:6
# time_low:17, time_high:17, device_low:15, device_high:15
# time_low:24, time_high:24, device_low:1, device_high:1
# time_low:29, time_high:29, device_low:10, device_high:10
# time_low:27, time_high:27, device_low:2, device_high:2
# time_low:22, time_high:22, device_low:11, device_high:11
# time_low:34, time_high:34, device_low:2, device_high:2
# time_low:22, time_high:22, device_low:1, device_high:1
# time_low:32, time_high:32, device_low:17, device_high:17
# time_low:34, time_high:34, device_low:8, device_high:8
# time_low:23, time_high:23, device_low:17, device_high:17
# time_low:39, time_high:39, device_low:1, device_high:1
# time_low:42, time_high:42, device_low:14, device_high:14
# time_low:54, time_high:54, device_low:13, device_high:13
# time_low:56, time_high:56, device_low:18, device_high:18
# time_low:56, time_high:56, device_low:8, device_high:8
# time_low:59, time_high:59, device_low:14, device_high:14
# time_low:49, time_high:49, device_low:8, device_high:8
# time_low:41, time_high:41, device_low:6, device_high:6
# time_low:47, time_high:47, device_low:9, device_high:9
# time_low:48, time_high:48, device_low:19, device_high:19
# time_low:56, time_high:56, device_low:20, device_high:20
# time_low:64, time_high:64, device_low:5, device_high:5
# time_low:74, time_high:74, device_low:4, device_high:4
# time_low:69, time_high:69, device_low:10, device_high:10
# time_low:68, time_high:68, device_low:4, device_high:4
# time_low:74, time_high:74, device_low:1, device_high:1
# time_low:65, time_high:65, device_low:13, device_high:13
# time_low:61, time_high:61, device_low:10, device_high:10
# time_low:78, time_high:78, device_low:2, device_high:2
# time_low:71, time_high:71, device_low:12, device_high:12
# time_low:63, time_high:63, device_low:2, device_high:2
# time_low:89, time_high:89, device_low:16, device_high:16
# time_low:96, time_high:96, device_low:15, device_high:15
# time_low:88, time_high:88, device_low:16, device_high:16
# time_low:82, time_high:82, device_low:8, device_high:8
# time_low:94, time_high:94, device_low:19, device_high:19
# time_low:83, time_high:83, device_low:17, device_high:17
# time_low:97, time_high:97, device_low:15, device_high:15
# time_low:83, time_high:83, device_low:6, device_high:6
# time_low:91, time_high:91, device_low:12, device_high:12
# time_low:82, time_high:82, device_low:9, device_high:9
# time_low:110, time_high:110, device_low:7, device_high:7
# time_low:119, time_high:119, device_low:16, device_high:16
# time_low:108, time_high:108, device_low:14, device_high:14
# time_low:103, time_high:103, device_low:19, device_high:19
# time_low:119, time_high:119, device_low:14, device_high:14
# time_low:102, time_high:102, device_low:16, device_high:16
# time_low:108, time_high:108, device_low:18, device_high:18
# time_low:109, time_high:109, device_low:5, device_high:5
# time_low:101, time_high:101, device_low:13, device_high:13
# time_low:118, time_high:118, device_low:15, device_high:15
# time_low:130, time_high:130, device_low:16, device_high:16
# time_low:131, time_high:131, device_low:1, device_high:1
# time_low:122, time_high:122, device_low:3, device_high:3
# time_low:120, time_high:120, device_low:19, device_high:19
# time_low:127, time_high:127, device_low:16, device_high:16
# time_low:128, time_high:128, device_low:3, device_high:3
# time_low:122, time_high:122, device_low:5, device_high:5
# time_low:134, time_high:134, device_low:4, device_high:4
# time_low:127, time_high:127, device_low:9, device_high:9
# time_low:128, time_high:128, device_low:16, device_high:16
# time_low:147, time_high:147, device_low:17, device_high:17
# time_low:148, time_high:148, device_low:6, device_high:6
# time_low:156, time_high:156, device_low:3, device_high:3
# time_low:140, time_high:140, device_low:19, device_high:19
# time_low:143, time_high:143, device_low:2, device_high:2
# time_low:140, time_high:140, device_low:16, device_high:16
# time_low:156, time_high:156, device_low:10, device_high:10
# time_low:149, time_high:149, device_low:7, device_high:7
# time_low:158, time_high:158, device_low:9, device_high:9
# time_low:158, time_high:158, device_low:19, device_high:19
# time_low:171, time_high:171, device_low:15, device_high:15
# time_low:166, time_high:166, device_low:14, device_high:14
# time_low:178, time_high:178, device_low:9, device_high:9
# time_low:160, time_high:160, device_low:7, device_high:7
# time_low:177, time_high:177, device_low:5, device_high:5
# time_low:167, time_high:167, device_low:8, device_high:8
# time_low:170, time_high:170, device_low:5, device_high:5
# time_low:162, time_high:162, device_low:14, device_high:14
# time_low:178, time_high:178, device_low:1, device_high:1
# time_low:173, time_high:173, device_low:5, device_high:5
# time_low:197, time_high:197, device_low:5, device_high:5
# time_low:182, time_high:182, device_low:14, device_high:14
# time_low:180, time_high:180, device_low:19, device_high:19
# time_low:195, time_high:195, device_low:10, device_high:10
# time_low:194, time_high:194, device_low:15, device_high:15
# time_low:192, time_high:192, device_low:13, device_high:13
# time_low:198, time_high:198, device_low:16, device_high:16
# time_low:197, time_high:197, device_low:6, device_high:6
# time_low:191, time_high:191, device_low:17, device_high:17
# time_low:196, time_high:196, device_low:15, device_high:15
# time_low:209, time_high:209, device_low:8, device_high:8
# time_low:217, time_high:217, device_low:9, device_high:9
# time_low:213, time_high:213, device_low:20, device_high:20
# time_low:210, time_high:210, device_low:5, device_high:5
# time_low:209, time_high:209, device_low:19, device_high:19
# time_low:202, time_high:202, device_low:1, device_high:1
# time_low:216, time_high:216, device_low:8, device_high:8
# time_low:207, time_high:207, device_low:7, device_high:7
# time_low:217, time_high:217, device_low:1, device_high:1
# time_low:209, time_high:209, device_low:16, device_high:16
# time_low:235, time_high:235, device_low:18, device_high:18
# time_low:226, time_high:226, device_low:5, device_high:5
# time_low:229, time_high:229, device_low:5, device_high:5
# time_low:238, time_high:238, device_low:14, device_high:14
# time_low:227, time_high:227, device_low:17, device_high:17
# time_low:228, time_high:228, device_low:4, device_high:4
# time_low:233, time_high:233, device_low:12, device_high:12
# time_low:220, time_high:220, device_low:11, device_high:11
# time_low:228, time_high:228, device_low:5, device_high:5
# time_low:220, time_high:220, device_low:5, device_high:5
# time_low:242, time_high:242, device_low:8, device_high:8
# time_low:252, time_high:252, device_low:1, device_high:1
# time_low:242, time_high:242, device_low:1, device_high:1
# time_low:240, time_high:240, device_low:17, device_high:17
# time_low:258, time_high:258, device_low:7, device_high:7
# time_low:253, time_high:253, device_low:6, device_high:6
# time_low:243, time_high:243, device_low:2, device_high:2
# time_low:247, time_high:247, device_low:18, device_high:18
# time_low:255, time_high:255, device_low:14, device_high:14
# time_low:248, time_high:248, device_low:4, device_high:4
# time_low:277, time_high:277, device_low:14, device_high:14
# time_low:265, time_high:265, device_low:11, device_high:11
# time_low:265, time_high:265, device_low:14, device_high:14
# time_low:279, time_high:279, device_low:18, device_high:18
# time_low:261, time_high:261, device_low:12, device_high:12
# time_low:267, time_high:267, device_low:14, device_high:14
# time_low:279, time_high:279, device_low:3, device_high:3
# time_low:260, time_high:260, device_low:7, device_high:7
# time_low:264, time_high:264, device_low:19, device_high:19
# time_low:264, time_high:264, device_low:5, device_high:5
# time_low:298, time_high:298, device_low:13, device_high:13
# time_low:285, time_high:285, device_low:8, device_high:8
# time_low:286, time_high:286, device_low:12, device_high:12
# time_low:281, time_high:281, device_low:6, device_high:6
# time_low:285, time_high:285, device_low:6, device_high:6
# time_low:287, time_high:287, device_low:12, device_high:12
# time_low:296, time_high:296, device_low:4, device_high:4
# time_low:281, time_high:281, device_low:8, device_high:8
# time_low:283, time_high:283, device_low:13, device_high:13
# time_low:293, time_high:293, device_low:7, device_high:7
# time_low:306, time_high:306, device_low:3, device_high:3
# time_low:316, time_high:316, device_low:14, device_high:14
# time_low:305, time_high:305, device_low:19, device_high:19
# time_low:306, time_high:306, device_low:12, device_high:12
# time_low:306, time_high:306, device_low:5, device_high:5
# time_low:302, time_high:302, device_low:20, device_high:20
# time_low:319, time_high:319, device_low:13, device_high:13
# time_low:312, time_high:312, device_low:10, device_high:10
# time_low:306, time_high:306, device_low:15, device_high:15
# time_low:300, time_high:300, device_low:16, device_high:16
# time_low:334, time_high:334, device_low:7, device_high:7
# time_low:330, time_high:330, device_low:19, device_high:19
# time_low:339, time_high:339, device_low:1, device_high:1
# time_low:320, time_high:320, device_low:3, device_high:3
# time_low:330, time_high:330, device_low:1, device_high:1
# time_low:331, time_high:331, device_low:15, device_high:15
# time_low:326, time_high:326, device_low:6, device_high:6
# time_low:333, time_high:333, device_low:12, device_high:12
# time_low:336, time_high:336, device_low:7, device_high:7
# time_low:323, time_high:323, device_low:18, device_high:18
# time_low:342, time_high:342, device_low:13, device_high:13
# time_low:357, time_high:357, device_low:11, device_high:11
# time_low:358, time_high:358, device_low:5, device_high:5
# time_low:354, time_high:354, device_low:7, device_high:7
# time_low:348, time_high:348, device_low:17, device_high:17
# time_low:359, time_high:359, device_low:17, device_high:17
# time_low:358, time_high:358, device_low:1, device_high:1
# time_low:340, time_high:340, device_low:19, device_high:19
# time_low:344, time_high:344, device_low:13, device_high:13
# time_low:356, time_high:356, device_low:1, device_high:1
# time_low:361, time_high:361, device_low:18, device_high:18
# time_low:379, time_high:379, device_low:14, device_high:14
# time_low:360, time_high:360, device_low:2, device_high:2
# time_low:366, time_high:366, device_low:9, device_high:9
# time_low:365, time_high:365, device_low:17, device_high:17
# time_low:363, time_high:363, device_low:12, device_high:12
# time_low:376, time_high:376, device_low:18, device_high:18
# time_low:374, time_high:374, device_low:3, device_high:3
# time_low:379, time_high:379, device_low:3, device_high:3
# time_low:360, time_high:360, device_low:20, device_high:20
# time_low:396, time_high:396, device_low:14, device_high:14
# time_low:387, time_high:387, device_low:1, device_high:1
# time_low:380, time_high:380, device_low:2, device_high:2
# time_low:385, time_high:385, device_low:16, device_high:16
# time_low:398, time_high:398, device_low:14, device_high:14
# time_low:399, time_high:399, device_low:3, device_high:3
# time_low:389, time_high:389, device_low:13, device_high:13
# time_low:399, time_high:399, device_low:4, device_high:4
# time_low:382, time_high:382, device_low:4, device_high:4
# time_low:386, time_high:386, device_low:19, device_high:19
# time_low:407, time_high:407, device_low:9, device_high:9
# time_low:408, time_high:408, device_low:3, device_high:3
# time_low:414, time_high:414, device_low:4, device_high:4
# time_low:411, time_high:411, device_low:8, device_high:8
# time_low:411, time_high:411, device_low:6, device_high:6
# time_low:413, time_high:413, device_low:17, device_high:17
# time_low:415, time_high:415, device_low:17, device_high:17
# time_low:401, time_high:401, device_low:15, device_high:15
# time_low:410, time_high:410, device_low:14, device_high:14
# time_low:414, time_high:414, device_low:16, device_high:16
# time_low:422, time_high:422, device_low:8, device_high:8
# time_low:423, time_high:423, device_low:4, device_high:4
# time_low:435, time_high:435, device_low:10, device_high:10
# time_low:430, time_high:430, device_low:7, device_high:7
# time_low:434, time_high:434, device_low:10, device_high:10
# time_low:439, time_high:439, device_low:15, device_high:15
# time_low:439, time_high:439, device_low:14, device_high:14
# time_low:425, time_high:425, device_low:5, device_high:5
# time_low:428, time_high:428, device_low:16, device_high:16
# time_low:426, time_high:426, device_low:15, device_high:15
# time_low:455, time_high:455, device_low:9, device_high:9
# time_low:442, time_high:442, device_low:10, device_high:10
# time_low:450, time_high:450, device_low:16, device_high:16
# time_low:450, time_high:450, device_low:5, device_high:5
# time_low:455, time_high:455, device_low:10, device_high:10
# time_low:459, time_high:459, device_low:10, device_high:10
# time_low:442, time_high:442, device_low:4, device_high:4
# time_low:449, time_high:449, device_low:11, device_high:11
# time_low:440, time_high:440, device_low:10, device_high:10
# time_low:451, time_high:451, device_low:9, device_high:9
# time_low:462, time_high:462, device_low:13, device_high:13
# time_low:462, time_high:462, device_low:3, device_high:3
# time_low:467, time_high:467, device_low:6, device_high:6
# time_low:473, time_high:473, device_low:10, device_high:10
# time_low:475, time_high:475, device_low:13, device_high:13
# time_low:470, time_high:470, device_low:19, device_high:19
# time_low:466, time_high:466, device_low:3, device_high:3
# time_low:464, time_high:464, device_low:5, device_high:5
# time_low:460, time_high:460, device_low:17, device_high:17
# time_low:477, time_high:477, device_low:10, device_high:10
# time_low:491, time_high:491, device_low:4, device_high:4
# time_low:484, time_high:484, device_low:10, device_high:10
# time_low:488, time_high:488, device_low:15, device_high:15
# time_low:499, time_high:499, device_low:11, device_high:11
# time_low:499, time_high:499, device_low:17, device_high:17
# time_low:485, time_high:485, device_low:20, device_high:20
# time_low:495, time_high:495, device_low:2, device_high:2
# time_low:481, time_high:481, device_low:7, device_high:7
# time_low:491, time_high:491, device_low:20, device_high:20
# time_low:488, time_high:488, device_low:20, device_high:20
# time_low:514, time_high:514, device_low:9, device_high:9
# time_low:502, time_high:502, device_low:19, device_high:19
# time_low:515, time_high:515, device_low:15, device_high:15
# time_low:514, time_high:514, device_low:18, device_high:18
# time_low:516, time_high:516, device_low:14, device_high:14
# time_low:500, time_high:500, device_low:16, device_high:16
# time_low:506, time_high:506, device_low:9, device_high:9
# time_low:504, time_high:504, device_low:20, device_high:20
# time_low:500, time_high:500, device_low:13, device_high:13
# time_low:518, time_high:518, device_low:12, device_high:12
# time_low:532, time_high:532, device_low:18, device_high:18
# time_low:534, time_high:534, device_low:20, device_high:20
# time_low:533, time_high:533, device_low:1, device_high:1
# time_low:535, time_high:535, device_low:16, device_high:16
# time_low:525, time_high:525, device_low:5, device_high:5
# time_low:533, time_high:533, device_low:16, device_high:16
# time_low:539, time_high:539, device_low:8, device_high:8
# time_low:537, time_high:537, device_low:5, device_high:5
# time_low:531, time_high:531, device_low:10, device_high:10
# time_low:528, time_high:528, device_low:17, device_high:17
# time_low:551, time_high:551, device_low:17, device_high:17
# time_low:556, time_high:556, device_low:7, device_high:7
# time_low:556, time_high:556, device_low:7, device_high:7
# time_low:553, time_high:553, device_low:1, device_high:1
# time_low:555, time_high:555, device_low:16, device_high:16
# time_low:556, time_high:556, device_low:11, device_high:11
# time_low:543, time_high:543, device_low:11, device_high:11
# time_low:557, time_high:557, device_low:17, device_high:17
# time_low:552, time_high:552, device_low:10, device_high:10
# time_low:544, time_high:544, device_low:18, device_high:18
# time_low:566, time_high:566, device_low:13, device_high:13
# time_low:574, time_high:574, device_low:7, device_high:7
# time_low:563, time_high:563, device_low:1, device_high:1
# time_low:577, time_high:577, device_low:18, device_high:18
# time_low:573, time_high:573, device_low:5, device_high:5
# time_low:563, time_high:563, device_low:5, device_high:5
# time_low:564, time_high:564, device_low:4, device_high:4
# time_low:576, time_high:576, device_low:7, device_high:7
# time_low:567, time_high:567, device_low:6, device_high:6
# time_low:560, time_high:560, device_low:13, device_high:13
# time_low:581, time_high:581, device_low:5, device_high:5
# time_low:580, time_high:580, device_low:4, device_high:4
# time_low:583, time_high:583, device_low:18, device_high:18
# time_low:590, time_high:590, device_low:5, device_high:5
# time_low:587, time_high:587, device_low:7, device_high:7
# time_low:597, time_high:597, device_low:11, device_high:11
# time_low:583, time_high:583, device_low:10, device_high:10
# time_low:593, time_high:593, device_low:4, device_high:4
# time_low:591, time_high:591, device_low:15, device_high:15
# time_low:583, time_high:583, device_low:14, device_high:14
# time_low:617, time_high:617, device_low:11, device_high:11
# time_low:615, time_high:615, device_low:17, device_high:17
# time_low:609, time_high:609, device_low:8, device_high:8
# time_low:603, time_high:603, device_low:12, device_high:12
# time_low:606, time_high:606, device_low:5, device_high:5
# time_low:613, time_high:613, device_low:7, device_high:7
# time_low:609, time_high:609, device_low:4, device_high:4
# time_low:606, time_high:606, device_low:20, device_high:20
# time_low:616, time_high:616, device_low:17, device_high:17
# time_low:608, time_high:608, device_low:13, device_high:13
# time_low:629, time_high:629, device_low:3, device_high:3
# time_low:623, time_high:623, device_low:1, device_high:1
# time_low:627, time_high:627, device_low:11, device_high:11
# time_low:639, time_high:639, device_low:18, device_high:18
# time_low:630, time_high:630, device_low:17, device_high:17
# time_low:630, time_high:630, device_low:15, device_high:15
# time_low:628, time_high:628, device_low:15, device_high:15
# time_low:633, time_high:633, device_low:3, device_high:3
# time_low:624, time_high:624, device_low:5, device_high:5
# time_low:633, time_high:633, device_low:6, device_high:6
# time_low:642, time_high:642, device_low:1, device_high:1
# time_low:652, time_high:652, device_low:19, device_high:19
# time_low:647, time_high:647, device_low:13, device_high:13
# time_low:659, time_high:659, device_low:14, device_high:14
# time_low:653, time_high:653, device_low:2, device_high:2
# time_low:652, time_high:652, device_low:9, device_high:9
# time_low:653, time_high:653, device_low:19, device_high:19
# time_low:653, time_high:653, device_low:5, device_high:5
# time_low:658, time_high:658, device_low:8, device_high:8
# time_low:644, time_high:644, device_low:4, device_high:4
# time_low:666, time_high:666, device_low:1, device_high:1
# time_low:668, time_high:668, device_low:18, device_high:18
# time_low:662, time_high:662, device_low:11, device_high:11
# time_low:667, time_high:667, device_low:19, device_high:19
# time_low:670, time_high:670, device_low:4, device_high:4
# time_low:679, time_high:679, device_low:20, device_high:20
# time_low:662, time_high:662, device_low:4, device_high:4
# time_low:671, time_high:671, device_low:4, device_high:4
# time_low:670, time_high:670, device_low:16, device_high:16
# time_low:678, time_high:678, device_low:7, device_high:7
# time_low:682, time_high:682, device_low:11, device_high:11
# time_low:683, time_high:683, device_low:18, device_high:18
# time_low:692, time_high:692, device_low:7, device_high:7
# time_low:680, time_high:680, device_low:11, device_high:11
# time_low:683, time_high:683, device_low:14, device_high:14
# time_low:685, time_high:685, device_low:17, device_high:17
# time_low:692, time_high:692, device_low:6, device_high:6
# time_low:688, time_high:688, device_low:9, device_high:9
# time_low:693, time_high:693, device_low:13, device_high:13
# time_low:692, time_high:692, device_low:11, device_high:11
# time_low:715, time_high:715, device_low:4, device_high:4
# time_low:706, time_high:706, device_low:9, device_high:9
# time_low:716, time_high:716, device_low:18, device_high:18
# time_low:704, time_high:704, device_low:3, device_high:3
# time_low:710, time_high:710, device_low:18, device_high:18
# time_low:710, time_high:710, device_low:13, device_high:13
# time_low:703, time_high:703, device_low:18, device_high:18
# time_low:702, time_high:702, device_low:6, device_high:6
# time_low:705, time_high:705, device_low:4, device_high:4
# time_low:715, time_high:715, device_low:10, device_high:10
# time_low:734, time_high:734, device_low:18, device_high:18
# time_low:733, time_high:733, device_low:9, device_high:9
# time_low:731, time_high:731, device_low:14, device_high:14
# time_low:726, time_high:726, device_low:11, device_high:11
# time_low:738, time_high:738, device_low:3, device_high:3
# time_low:727, time_high:727, device_low:1, device_high:1
# time_low:732, time_high:732, device_low:17, device_high:17
# time_low:737, time_high:737, device_low:14, device_high:14
# time_low:739, time_high:739, device_low:10, device_high:10
# time_low:729, time_high:729, device_low:6, device_high:6
# time_low:742, time_high:742, device_low:5, device_high:5
# time_low:756, time_high:756, device_low:10, device_high:10
# time_low:743, time_high:743, device_low:16, device_high:16
# time_low:743, time_high:743, device_low:16, device_high:16
# time_low:741, time_high:741, device_low:14, device_high:14
# time_low:746, time_high:746, device_low:11, device_high:11
# time_low:740, time_high:740, device_low:7, device_high:7
# time_low:758, time_high:758, device_low:14, device_high:14
# time_low:749, time_high:749, device_low:6, device_high:6
# time_low:745, time_high:745, device_low:9, device_high:9
# time_low:765, time_high:765, device_low:17, device_high:17
# time_low:762, time_high:762, device_low:6, device_high:6
# time_low:779, time_high:779, device_low:18, device_high:18
# time_low:769, time_high:769, device_low:15, device_high:15
# time_low:779, time_high:779, device_low:13, device_high:13
# time_low:762, time_high:762, device_low:9, device_high:9
# time_low:779, time_high:779, device_low:20, device_high:20
# time_low:763, time_high:763, device_low:2, device_high:2
# time_low:775, time_high:775, device_low:6, device_high:6
# time_low:763, time_high:763, device_low:15, device_high:15
# time_low:784, time_high:784, device_low:2, device_high:2
# time_low:781, time_high:781, device_low:16, device_high:16
# time_low:796, time_high:796, device_low:11, device_high:11
# time_low:782, time_high:782, device_low:10, device_high:10
# time_low:797, time_high:797, device_low:5, device_high:5
# time_low:799, time_high:799, device_low:9, device_high:9
# time_low:799, time_high:799, device_low:6, device_high:6
# time_low:785, time_high:785, device_low:16, device_high:16
# time_low:798, time_high:798, device_low:1, device_high:1
# time_low:792, time_high:792, device_low:3, device_high:3
# time_low:804, time_high:804, device_low:2, device_high:2
# time_low:803, time_high:803, device_low:1, device_high:1
# time_low:817, time_high:817, device_low:7, device_high:7
# time_low:814, time_high:814, device_low:17, device_high:17
# time_low:800, time_high:800, device_low:5, device_high:5
# time_low:801, time_high:801, device_low:3, device_high:3
# time_low:802, time_high:802, device_low:14, device_high:14
# time_low:816, time_high:816, device_low:11, device_high:11
# time_low:803, time_high:803, device_low:14, device_high:14
# time_low:808, time_high:808, device_low:4, device_high:4
# time_low:825, time_high:825, device_low:6, device_high:6
# time_low:838, time_high:838, device_low:7, device_high:7
# time_low:837, time_high:837, device_low:15, device_high:15
# time_low:826, time_high:826, device_low:2, device_high:2
# time_low:830, time_high:830, device_low:1, device_high:1
# time_low:839, time_high:839, device_low:10, device_high:10
# time_low:829, time_high:829, device_low:11, device_high:11
# time_low:826, time_high:826, device_low:1, device_high:1
# time_low:826, time_high:826, device_low:19, device_high:19
# time_low:825, time_high:825, device_low:12, device_high:12
# time_low:858, time_high:858, device_low:6, device_high:6
# time_low:849, time_high:849, device_low:7, device_high:7
# time_low:849, time_high:849, device_low:14, device_high:14
# time_low:846, time_high:846, device_low:10, device_high:10
# time_low:847, time_high:847, device_low:7, device_high:7
# time_low:859, time_high:859, device_low:14, device_high:14
# time_low:849, time_high:849, device_low:3, device_high:3
# time_low:843, time_high:843, device_low:13, device_high:13
# time_low:852, time_high:852, device_low:1, device_high:1
# time_low:856, time_high:856, device_low:3, device_high:3
# time_low:872, time_high:872, device_low:9, device_high:9
# time_low:869, time_high:869, device_low:19, device_high:19
# time_low:861, time_high:861, device_low:1, device_high:1
# time_low:861, time_high:861, device_low:15, device_high:15
# time_low:863, time_high:863, device_low:17, device_high:17
# time_low:864, time_high:864, device_low:13, device_high:13
# time_low:870, time_high:870, device_low:13, device_high:13
# time_low:861, time_high:861, device_low:18, device_high:18
# time_low:874, time_high:874, device_low:8, device_high:8
# time_low:875, time_high:875, device_low:2, device_high:2
# time_low:885, time_high:885, device_low:16, device_high:16
# time_low:898, time_high:898, device_low:5, device_high:5
# time_low:882, time_high:882, device_low:4, device_high:4
# time_low:890, time_high:890, device_low:5, device_high:5
# time_low:887, time_high:887, device_low:11, device_high:11
# time_low:884, time_high:884, device_low:9, device_high:9
# time_low:888, time_high:888, device_low:13, device_high:13
# time_low:898, time_high:898, device_low:11, device_high:11
# time_low:881, time_high:881, device_low:6, device_high:6
# time_low:895, time_high:895, device_low:5, device_high:5
# time_low:907, time_high:907, device_low:11, device_high:11
# time_low:906, time_high:906, device_low:4, device_high:4
# time_low:907, time_high:907, device_low:15, device_high:15
# time_low:905, time_high:905, device_low:16, device_high:16
# time_low:905, time_high:905, device_low:10, device_high:10
# time_low:915, time_high:915, device_low:7, device_high:7
# time_low:909, time_high:909, device_low:6, device_high:6
# time_low:919, time_high:919, device_low:8, device_high:8
# time_low:911, time_high:911, device_low:5, device_high:5
# time_low:901, time_high:901, device_low:19, device_high:19
# time_low:924, time_high:924, device_low:11, device_high:11
# time_low:920, time_high:920, device_low:10, device_high:10
# time_low:928, time_high:928, device_low:9, device_high:9
# time_low:935, time_high:935, device_low:17, device_high:17
# time_low:934, time_high:934, device_low:17, device_high:17
# time_low:935, time_high:935, device_low:18, device_high:18
# time_low:931, time_high:931, device_low:17, device_high:17
# time_low:933, time_high:933, device_low:8, device_high:8
# time_low:925, time_high:925, device_low:10, device_high:10
# time_low:930, time_high:930, device_low:8, device_high:8
# time_low:951, time_high:951, device_low:17, device_high:17
# time_low:956, time_high:956, device_low:3, device_high:3
# time_low:957, time_high:957, device_low:11, device_high:11
# time_low:948, time_high:948, device_low:19, device_high:19
# time_low:945, time_high:945, device_low:3, device_high:3
# time_low:946, time_high:946, device_low:1, device_high:1
# time_low:945, time_high:945, device_low:11, device_high:11
# time_low:948, time_high:948, device_low:3, device_high:3
# time_low:955, time_high:955, device_low:3, device_high:3
# time_low:946, time_high:946, device_low:19, device_high:19
# time_low:974, time_high:974, device_low:1, device_high:1
# time_low:973, time_high:973, device_low:20, device_high:20
# time_low:961, time_high:961, device_low:5, device_high:5
# time_low:973, time_high:973, device_low:10, device_high:10
# time_low:971, time_high:971, device_low:2, device_high:2
# time_low:978, time_high:978, device_low:7, device_high:7
# time_low:969, time_high:969, device_low:5, device_high:5
# time_low:979, time_high:979, device_low:15, device_high:15
# time_low:968, time_high:968, device_low:7, device_high:7
# time_low:964, time_high:964, device_low:1, device_high:1
# time_low:986, time_high:986, device_low:20, device_high:20
# time_low:980, time_high:980, device_low:17, device_high:17
# time_low:984, time_high:984, device_low:11, device_high:11
# time_low:982, time_high:982, device_low:13, device_high:13
# time_low:985, time_high:985, device_low:14, device_high:14
# time_low:980, time_high:980, device_low:17, device_high:17
# time_low:983, time_high:983, device_low:5, device_high:5
# time_low:999, time_high:999, device_low:18, device_high:18
# time_low:995, time_high:995, device_low:12, device_high:12
# time_low:985, time_high:985, device_low:12, device_high:12
# time_low:1013, time_high:1013, device_low:7, device_high:7
# time_low:1002, time_high:1002, device_low:19, device_high:19
# time_low:1007, time_high:1007, device_low:15, device_high:15
# time_low:1019, time_high:1019, device_low:16, device_high:16
# time_low:1001, time_high:1001, device_low:14, device_high:14
# time_low:1008, time_high:1008, device_low:12, device_high:12
# time_low:1003, time_high:1003, device_low:5, device_high:5
# time_low:1006, time_high:1006, device_low:4, device_high:4
# time_low:1015, time_high:1015, device_low:16, device_high:16
# time_low:1007, time_high:1007, device_low:14, device_high:14
# time_low:1024, time_high:1024, device_low:13, device_high:13
# time_low:1035, time_high:1035, device_low:12, device_high:12
# time_low:1021, time_high:1021, device_low:11, device_high:11
# time_low:1035, time_high:1035, device_low:7, device_high:7
# time_low:1031, time_high:1031, device_low:17, device_high:17
# time_low:1030, time_high:1030, device_low:16, device_high:16
# time_low:1032, time_high:1032, device_low:1, device_high:1
# time_low:1020, time_high:1020, device_low:11, device_high:11
# time_low:1026, time_high:1026, device_low:8, device_high:8
# time_low:1039, time_high:1039, device_low:7, device_high:7
# time_low:1052, time_high:1052, device_low:9, device_high:9
# time_low:1046, time_high:1046, device_low:5, device_high:5
# time_low:1044, time_high:1044, device_low:8, device_high:8
# time_low:1059, time_high:1059, device_low:2, device_high:2
# time_low:1049, time_high:1049, device_low:1, device_high:1
# time_low:1047, time_high:1047, device_low:8, device_high:8
# time_low:1042, time_high:1042, device_low:16, device_high:16
# time_low:1048, time_high:1048, device_low:3, device_high:3
# time_low:1048, time_high:1048, device_low:1, device_high:1
# time_low:1043, time_high:1043, device_low:6, device_high:6
# time_low:1071, time_high:1071, device_low:2, device_high:2
# time_low:1068, time_high:1068, device_low:15, device_high:15
# time_low:1076, time_high:1076, device_low:14, device_high:14
# time_low:1068, time_high:1068, device_low:16, device_high:16
# time_low:1060, time_high:1060, device_low:18, device_high:18
# time_low:1070, time_high:1070, device_low:19, device_high:19
# time_low:1067, time_high:1067, device_low:3, device_high:3
# time_low:1078, time_high:1078, device_low:3, device_high:3
# time_low:1075, time_high:1075, device_low:4, device_high:4
# time_low:1070, time_high:1070, device_low:6, device_high:6
# time_low:1095, time_high:1095, device_low:8, device_high:8
# time_low:1094, time_high:1094, device_low:15, device_high:15
# time_low:1083, time_high:1083, device_low:10, device_high:10
# time_low:1097, time_high:1097, device_low:7, device_high:7
# time_low:1082, time_high:1082, device_low:18, device_high:18
# time_low:1094, time_high:1094, device_low:10, device_high:10
# time_low:1084, time_high:1084, device_low:1, device_high:1
# time_low:1095, time_high:1095, device_low:15, device_high:15
# time_low:1094, time_high:1094, device_low:17, device_high:17
# time_low:1087, time_high:1087, device_low:8, device_high:8
# time_low:1113, time_high:1113, device_low:6, device_high:6
# time_low:1100, time_high:1100, device_low:5, device_high:5
# time_low:1101, time_high:1101, device_low:14, device_high:14
# time_low:1105, time_high:1105, device_low:1, device_high:1
# time_low:1108, time_high:1108, device_low:2, device_high:2
# time_low:1119, time_high:1119, device_low:14, device_high:14
# time_low:1110, time_high:1110, device_low:6, device_high:6
# time_low:1102, time_high:1102, device_low:8, device_high:8
# time_low:1105, time_high:1105, device_low:5, device_high:5
# time_low:1105, time_high:1105, device_low:1, device_high:1
# time_low:1123, time_high:1123, device_low:15, device_high:15
# time_low:1124, time_high:1124, device_low:13, device_high:13
# time_low:1130, time_high:1130, device_low:12, device_high:12
# time_low:1133, time_high:1133, device_low:14, device_high:14
# time_low:1136, time_high:1136, device_low:16, device_high:16
# time_low:1135, time_high:1135, device_low:8, device_high:8
# time_low:1137, time_high:1137, device_low:17, device_high:17
# time_low:1128, time_high:1128, device_low:12, device_high:12
# time_low:1125, time_high:1125, device_low:19, device_high:19
# time_low:1126, time_high:1126, device_low:3, device_high:3
# time_low:1141, time_high:1141, device_low:9, device_high:9
# time_low:1146, time_high:1146, device_low:15, device_high:15
# time_low:1143, time_high:1143, device_low:20, device_high:20
# time_low:1152, time_high:1152, device_low:12, device_high:12
# time_low:1148, time_high:1148, device_low:14, device_high:14
# time_low:1144, time_high:1144, device_low:11, device_high:11
# time_low:1150, time_high:1150, device_low:16, device_high:16
# time_low:1143, time_high:1143, device_low:4, device_high:4
# time_low:1157, time_high:1157, device_low:18, device_high:18
# time_low:1159, time_high:1159, device_low:1, device_high:1
# time_low:1168, time_high:1168, device_low:18, device_high:18
# time_low:1174, time_high:1174, device_low:15, device_high:15
# time_low:1165, time_high:1165, device_low:6, device_high:6
# time_low:1173, time_high:1173, device_low:9, device_high:9
# time_low:1170, time_high:1170, device_low:15, device_high:15
# time_low:1160, time_high:1160, device_low:7, device_high:7
# time_low:1162, time_high:1162, device_low:2, device_high:2
# time_low:1173, time_high:1173, device_low:18, device_high:18
# time_low:1161, time_high:1161, device_low:7, device_high:7
# time_low:1176, time_high:1176, device_low:14, device_high:14
# time_low:1182, time_high:1182, device_low:20, device_high:20
# time_low:1185, time_high:1185, device_low:16, device_high:16
# time_low:1182, time_high:1182, device_low:17, device_high:17
# time_low:1187, time_high:1187, device_low:2, device_high:2
# time_low:1198, time_high:1198, device_low:9, device_high:9
# time_low:1190, time_high:1190, device_low:13, device_high:13
# time_low:1195, time_high:1195, device_low:9, device_high:9
# time_low:1188, time_high:1188, device_low:17, device_high:17
# time_low:1198, time_high:1198, device_low:13, device_high:13
# time_low:1187, time_high:1187, device_low:18, device_high:18
# time_low:1207, time_high:1207, device_low:5, device_high:5
# time_low:1214, time_high:1214, device_low:10, device_high:10
# time_low:1214, time_high:1214, device_low:3, device_high:3
# time_low:1210, time_high:1210, device_low:4, device_high:4
# time_low:1217, time_high:1217, device_low:7, device_high:7
# time_low:1214, time_high:1214, device_low:20, device_high:20
# time_low:1216, time_high:1216, device_low:15, device_high:15
# time_low:1217, time_high:1217, device_low:20, device_high:20
# time_low:1212, time_high:1212, device_low:20, device_high:20
# time_low:1209, time_high:1209, device_low:15, device_high:15
# time_low:1225, time_high:1225, device_low:10, device_high:10
# time_low:1239, time_high:1239, device_low:19, device_high:19
# time_low:1225, time_high:1225, device_low:15, device_high:15
# time_low:1227, time_high:1227, device_low:10, device_high:10
# time_low:1234, time_high:1234, device_low:2, device_high:2
# time_low:1228, time_high:1228, device_low:18, device_high:18
# time_low:1228, time_high:1228, device_low:5, device_high:5
# time_low:1235, time_high:1235, device_low:2, device_high:2
# time_low:1238, time_high:1238, device_low:7, device_high:7
# time_low:1232, time_high:1232, device_low:9, device_high:9
# time_low:1243, time_high:1243, device_low:19, device_high:19
# time_low:1253, time_high:1253, device_low:2, device_high:2
# time_low:1252, time_high:1252, device_low:12, device_high:12
# time_low:1243, time_high:1243, device_low:13, device_high:13
# time_low:1242, time_high:1242, device_low:8, device_high:8
# time_low:1242, time_high:1242, device_low:18, device_high:18
# time_low:1257, time_high:1257, device_low:13, device_high:13
# time_low:1254, time_high:1254, device_low:16, device_high:16
# time_low:1253, time_high:1253, device_low:5, device_high:5
# time_low:1256, time_high:1256, device_low:5, device_high:5
# time_low:1270, time_high:1270, device_low:4, device_high:4
# time_low:1270, time_high:1270, device_low:19, device_high:19
# time_low:1276, time_high:1276, device_low:11, device_high:11
# time_low:1266, time_high:1266, device_low:13, device_high:13
# time_low:1273, time_high:1273, device_low:2, device_high:2
# time_low:1263, time_high:1263, device_low:6, device_high:6
# time_low:1272, time_high:1272, device_low:3, device_high:3
# time_low:1278, time_high:1278, device_low:14, device_high:14
# time_low:1263, time_high:1263, device_low:10, device_high:10
# time_low:1274, time_high:1274, device_low:17, device_high:17
# time_low:1296, time_high:1296, device_low:9, device_high:9
# time_low:1294, time_high:1294, device_low:3, device_high:3
# time_low:1298, time_high:1298, device_low:5, device_high:5
# time_low:1299, time_high:1299, device_low:17, device_high:17
# time_low:1280, time_high:1280, device_low:13, device_high:13
# time_low:1297, time_high:1297, device_low:5, device_high:5
# time_low:1297, time_high:1297, device_low:2, device_high:2
# time_low:1299, time_high:1299, device_low:7, device_high:7
# time_low:1289, time_high:1289, device_low:2, device_high:2
# time_low:1287, time_high:1287, device_low:14, device_high:14
# time_low:1315, time_high:1315, device_low:7, device_high:7
# time_low:1315, time_high:1315, device_low:5, device_high:5
# time_low:1300, time_high:1300, device_low:13, device_high:13
# time_low:1311, time_high:1311, device_low:12, device_high:12
# time_low:1318, time_high:1318, device_low:11, device_high:11
# time_low:1301, time_high:1301, device_low:18, device_high:18
# time_low:1318, time_high:1318, device_low:3, device_high:3
# time_low:1309, time_high:1309, device_low:7, device_high:7
# time_low:1313, time_high:1313, device_low:1, device_high:1
# time_low:1312, time_high:1312, device_low:11, device_high:11
# time_low:1339, time_high:1339, device_low:15, device_high:15
# time_low:1328, time_high:1328, device_low:20, device_high:20
# time_low:1322, time_high:1322, device_low:15, device_high:15
# time_low:1327, time_high:1327, device_low:11, device_high:11
# time_low:1335, time_high:1335, device_low:18, device_high:18
# time_low:1320, time_high:1320, device_low:7, device_high:7
# time_low:1324, time_high:1324, device_low:7, device_high:7
# time_low:1333, time_high:1333, device_low:12, device_high:12
# time_low:1323, time_high:1323, device_low:7, device_high:7
# time_low:1330, time_high:1330, device_low:18, device_high:18
# time_low:1351, time_high:1351, device_low:17, device_high:17
# time_low:1346, time_high:1346, device_low:9, device_high:9
# time_low:1352, time_high:1352, device_low:4, device_high:4
# time_low:1344, time_high:1344, device_low:16, device_high:16
# time_low:1354, time_high:1354, device_low:19, device_high:19
# time_low:1343, time_high:1343, device_low:8, device_high:8
# time_low:1347, time_high:1347, device_low:20, device_high:20
# time_low:1341, time_high:1341, device_low:13, device_high:13
# time_low:1343, time_high:1343, device_low:20, device_high:20
# time_low:1350, time_high:1350, device_low:13, device_high:13
# time_low:1360, time_high:1360, device_low:1, device_high:1
# time_low:1360, time_high:1360, device_low:7, device_high:7
# time_low:1378, time_high:1378, device_low:5, device_high:5
# time_low:1364, time_high:1364, device_low:5, device_high:5
# time_low:1371, time_high:1371, device_low:1, device_high:1
# time_low:1374, time_high:1374, device_low:2, device_high:2
# time_low:1377, time_high:1377, device_low:11, device_high:11
# time_low:1364, time_high:1364, device_low:8, device_high:8
# time_low:1366, time_high:1366, device_low:2, device_high:2
# time_low:1377, time_high:1377, device_low:18, device_high:18
# time_low:1393, time_high:1393, device_low:17, device_high:17
# time_low:1381, time_high:1381, device_low:19, device_high:19
# time_low:1396, time_high:1396, device_low:4, device_high:4
# time_low:1399, time_high:1399, device_low:17, device_high:17
# time_low:1392, time_high:1392, device_low:5, device_high:5
# time_low:1390, time_high:1390, device_low:11, device_high:11
# time_low:1389, time_high:1389, device_low:16, device_high:16
# time_low:1380, time_high:1380, device_low:13, device_high:13
# time_low:1380, time_high:1380, device_low:5, device_high:5
# time_low:1382, time_high:1382, device_low:8, device_high:8
# time_low:1402, time_high:1402, device_low:10, device_high:10
# time_low:1412, time_high:1412, device_low:4, device_high:4
# time_low:1406, time_high:1406, device_low:14, device_high:14
# time_low:1401, time_high:1401, device_low:8, device_high:8
# time_low:1412, time_high:1412, device_low:9, device_high:9
# time_low:1408, time_high:1408, device_low:11, device_high:11
# time_low:1418, time_high:1418, device_low:16, device_high:16
# time_low:1400, time_high:1400, device_low:20, device_high:20
# time_low:1413, time_high:1413, device_low:16, device_high:16
# time_low:1413, time_high:1413, device_low:4, device_high:4
# time_low:1421, time_high:1421, device_low:12, device_high:12
# time_low:1427, time_high:1427, device_low:10, device_high:10
# time_low:1423, time_high:1423, device_low:3, device_high:3
# time_low:1437, time_high:1437, device_low:18, device_high:18
# time_low:1432, time_high:1432, device_low:12, device_high:12
# time_low:1421, time_high:1421, device_low:8, device_high:8
# time_low:1428, time_high:1428, device_low:12, device_high:12
# time_low:1432, time_high:1432, device_low:15, device_high:15
# time_low:1427, time_high:1427, device_low:3, device_high:3
# time_low:1424, time_high:1424, device_low:19, device_high:19
# time_low:1456, time_high:1456, device_low:17, device_high:17
# time_low:1443, time_high:1443, device_low:3, device_high:3
# time_low:1457, time_high:1457, device_low:1, device_high:1
# time_low:1452, time_high:1452, device_low:20, device_high:20
# time_low:1441, time_high:1441, device_low:19, device_high:19
# time_low:1451, time_high:1451, device_low:7, device_high:7
# time_low:1455, time_high:1455, device_low:18, device_high:18
# time_low:1459, time_high:1459, device_low:7, device_high:7
# time_low:1458, time_high:1458, device_low:19, device_high:19
# time_low:1446, time_high:1446, device_low:5, device_high:5
# time_low:1466, time_high:1466, device_low:3, device_high:3
# time_low:1470, time_high:1470, device_low:2, device_high:2
# time_low:1474, time_high:1474, device_low:1, device_high:1
# time_low:1469, time_high:1469, device_low:10, device_high:10
# time_low:1466, time_high:1466, device_low:12, device_high:12
# time_low:1474, time_high:1474, device_low:5, device_high:5
# time_low:1475, time_high:1475, device_low:16, device_high:16
# time_low:1461, time_high:1461, device_low:11, device_high:11
# time_low:1463, time_high:1463, device_low:16, device_high:16
# time_low:1474, time_high:1474, device_low:2, device_high:2
# time_low:1492, time_high:1492, device_low:3, device_high:3
# time_low:1483, time_high:1483, device_low:14, device_high:14
# time_low:1494, time_high:1494, device_low:6, device_high:6
# time_low:1482, time_high:1482, device_low:15, device_high:15
# time_low:1486, time_high:1486, device_low:10, device_high:10
# time_low:1492, time_high:1492, device_low:20, device_high:20
# time_low:1493, time_high:1493, device_low:13, device_high:13
# time_low:1493, time_high:1493, device_low:2, device_high:2
# time_low:1483, time_high:1483, device_low:18, device_high:18
# time_low:1485, time_high:1485, device_low:13, device_high:13
# time_low:1519, time_high:1519, device_low:20, device_high:20
# time_low:1503, time_high:1503, device_low:13, device_high:13
# time_low:1513, time_high:1513, device_low:4, device_high:4
# time_low:1506, time_high:1506, device_low:19, device_high:19
# time_low:1519, time_high:1519, device_low:9, device_high:9
# time_low:1501, time_high:1501, device_low:4, device_high:4
# time_low:1517, time_high:1517, device_low:19, device_high:19
# time_low:1515, time_high:1515, device_low:20, device_high:20
# time_low:1503, time_high:1503, device_low:4, device_high:4
# time_low:1503, time_high:1503, device_low:9, device_high:9
# time_low:1527, time_high:1527, device_low:19, device_high:19
# time_low:1528, time_high:1528, device_low:18, device_high:18
# time_low:1526, time_high:1526, device_low:2, device_high:2
# time_low:1531, time_high:1531, device_low:19, device_high:19
# time_low:1524, time_high:1524, device_low:12, device_high:12
# time_low:1521, time_high:1521, device_low:2, device_high:2
# time_low:1534, time_high:1534, device_low:11, device_high:11
# time_low:1534, time_high:1534, device_low:9, device_high:9
# time_low:1531, time_high:1531, device_low:7, device_high:7
# time_low:1537, time_high:1537, device_low:6, device_high:6
# time_low:1559, time_high:1559, device_low:2, device_high:2
# time_low:1559, time_high:1559, device_low:1, device_high:1
# time_low:1550, time_high:1550, device_low:3, device_high:3
# time_low:1544, time_high:1544, device_low:6, device_high:6
# time_low:1557, time_high:1557, device_low:10, device_high:10
# time_low:1558, time_high:1558, device_low:13, device_high:13
# time_low:1543, time_high:1543, device_low:19, device_high:19
# time_low:1552, time_high:1552, device_low:15, device_high:15
# time_low:1554, time_high:1554, device_low:16, device_high:16
# time_low:1554, time_high:1554, device_low:15, device_high:15
# time_low:1561, time_high:1561, device_low:6, device_high:6
# time_low:1577, time_high:1577, device_low:17, device_high:17
# time_low:1561, time_high:1561, device_low:8, device_high:8
# time_low:1573, time_high:1573, device_low:6, device_high:6
# time_low:1573, time_high:1573, device_low:15, device_high:15
# time_low:1575, time_high:1575, device_low:13, device_high:13
# time_low:1570, time_high:1570, device_low:4, device_high:4
# time_low:1568, time_high:1568, device_low:15, device_high:15
# time_low:1567, time_high:1567, device_low:2, device_high:2
# time_low:1571, time_high:1571, device_low:8, device_high:8
# time_low:1597, time_high:1597, device_low:15, device_high:15
# time_low:1589, time_high:1589, device_low:17, device_high:17
# time_low:1590, time_high:1590, device_low:1, device_high:1
# time_low:1588, time_high:1588, device_low:16, device_high:16
# time_low:1599, time_high:1599, device_low:15, device_high:15
# time_low:1583, time_high:1583, device_low:19, device_high:19
# time_low:1591, time_high:1591, device_low:16, device_high:16
# time_low:1591, time_high:1591, device_low:1, device_high:1
# time_low:1592, time_high:1592, device_low:8, device_high:8
# time_low:1582, time_high:1582, device_low:18, device_high:18
# time_low:1604, time_high:1604, device_low:4, device_high:4
# time_low:1614, time_high:1614, device_low:10, device_high:10
# time_low:1612, time_high:1612, device_low:19, device_high:19
# time_low:1607, time_high:1607, device_low:16, device_high:16
# time_low:1611, time_high:1611, device_low:4, device_high:4
# time_low:1614, time_high:1614, device_low:20, device_high:20
# time_low:1605, time_high:1605, device_low:18, device_high:18
# time_low:1612, time_high:1612, device_low:1, device_high:1
# time_low:1617, time_high:1617, device_low:8, device_high:8
# time_low:1614, time_high:1614, device_low:8, device_high:8
# time_low:1635, time_high:1635, device_low:17, device_high:17
# time_low:1624, time_high:1624, device_low:14, device_high:14
# time_low:1639, time_high:1639, device_low:19, device_high:19
# time_low:1639, time_high:1639, device_low:16, device_high:16
# time_low:1639, time_high:1639, device_low:11, device_high:11
# time_low:1628, time_high:1628, device_low:6, device_high:6
# time_low:1630, time_high:1630, device_low:14, device_high:14
# ...
# time_low:2469, time_high:2469, device_low:7, device_high:7
# time_low:2478, time_high:2478, device_low:3, device_high:3
# time_low:2478, time_high:2478, device_low:13, device_high:13
# time_low:2476, time_high:2476, device_low:5, device_high:5
# time_low:2466, time_high:2466, device_low:19, device_high:19
# time_low:2476, time_high:2476, device_low:1, device_high:1
# time_low:2496, time_high:2496, device_low:9, device_high:9
# time_low:2487, time_high:2487, device_low:2, device_high:2
# time_low:2483, time_high:2483, device_low:13, device_high:13
# time_low:2491, time_high:2491, device_low:17, device_high:17
# time_low:2494, time_high:2494, device_low:11, device_high:11
# time_low:2494, time_high:2494, device_low:2, device_high:2
# time_low:2490, time_high:2490, device_low:17, device_high:17
# time_low:2494, time_high:2494, device_low:15, device_high:15
# time_low:2494, time_high:2494, device_low:5, device_high:5
# time_low:2497, time_high:2497, device_low:17, device_high:17
# time_low:2500, time_high:2500, device_low:20, device_high:20
# time_low:2502, time_high:2502, device_low:13, device_high:13
# time_low:2504, time_high:2504, device_low:4, device_high:4
# time_low:2504, time_high:2504, device_low:12, device_high:12
# time_low:2505, time_high:2505, device_low:4, device_high:4
# time_low:2503, time_high:2503, device_low:14, device_high:14
# time_low:2509, time_high:2509, device_low:7, device_high:7
# time_low:2516, time_high:2516, device_low:11, device_high:11
# time_low:2500, time_high:2500, device_low:7, device_high:7
# time_low:2507, time_high:2507, device_low:9, device_high:9
# time_low:2524, time_high:2524, device_low:5, device_high:5
# time_low:2530, time_high:2530, device_low:6, device_high:6
# time_low:2524, time_high:2524, device_low:11, device_high:11
# time_low:2539, time_high:2539, device_low:17, device_high:17
# time_low:2523, time_high:2523, device_low:7, device_high:7
# time_low:2539, time_high:2539, device_low:19, device_high:19
# time_low:2521, time_high:2521, device_low:14, device_high:14
# time_low:2528, time_high:2528, device_low:12, device_high:12
# time_low:2531, time_high:2531, device_low:1, device_high:1
# time_low:2527, time_high:2527, device_low:18, device_high:18
# time_low:2557, time_high:2557, device_low:6, device_high:6
# time_low:2543, time_high:2543, device_low:1, device_high:1
# time_low:2554, time_high:2554, device_low:5, device_high:5
# time_low:2542, time_high:2542, device_low:2, device_high:2
# time_low:2554, time_high:2554, device_low:13, device_high:13
# time_low:2549, time_high:2549, device_low:20, device_high:20
# time_low:2553, time_high:2553, device_low:1, device_high:1
# time_low:2558, time_high:2558, device_low:7, device_high:7
# time_low:2549, time_high:2549, device_low:5, device_high:5
# time_low:2559, time_high:2559, device_low:15, device_high:15
# time_low:2562, time_high:2562, device_low:5, device_high:5
# time_low:2563, time_high:2563, device_low:20, device_high:20
# time_low:2579, time_high:2579, device_low:4, device_high:4
# time_low:2562, time_high:2562, device_low:14, device_high:14
# time_low:2577, time_high:2577, device_low:6, device_high:6
# time_low:2569, time_high:2569, device_low:17, device_high:17
# time_low:2570, time_high:2570, device_low:20, device_high:20
# time_low:2564, time_high:2564, device_low:17, device_high:17
# time_low:2575, time_high:2575, device_low:10, device_high:10
# time_low:2563, time_high:2563, device_low:6, device_high:6
# time_low:2592, time_high:2592, device_low:17, device_high:17
# time_low:2583, time_high:2583, device_low:13, device_high:13
# time_low:2593, time_high:2593, device_low:9, device_high:9
# time_low:2596, time_high:2596, device_low:4, device_high:4
# time_low:2585, time_high:2585, device_low:10, device_high:10
# time_low:2599, time_high:2599, device_low:5, device_high:5
# time_low:2597, time_high:2597, device_low:6, device_high:6
# time_low:2582, time_high:2582, device_low:9, device_high:9
# time_low:2592, time_high:2592, device_low:20, device_high:20
# time_low:2582, time_high:2582, device_low:12, device_high:12
# time_low:2601, time_high:2601, device_low:10, device_high:10
# time_low:2602, time_high:2602, device_low:7, device_high:7
# time_low:2619, time_high:2619, device_low:9, device_high:9
# time_low:2617, time_high:2617, device_low:11, device_high:11
# time_low:2611, time_high:2611, device_low:16, device_high:16
# time_low:2619, time_high:2619, device_low:4, device_high:4
# time_low:2610, time_high:2610, device_low:17, device_high:17
# time_low:2606, time_high:2606, device_low:13, device_high:13
# time_low:2603, time_high:2603, device_low:5, device_high:5
# time_low:2614, time_high:2614, device_low:10, device_high:10
# time_low:2639, time_high:2639, device_low:9, device_high:9
# time_low:2622, time_high:2622, device_low:6, device_high:6
# time_low:2633, time_high:2633, device_low:15, device_high:15
# time_low:2627, time_high:2627, device_low:3, device_high:3
# time_low:2638, time_high:2638, device_low:14, device_high:14
# time_low:2638, time_high:2638, device_low:1, device_high:1
# time_low:2621, time_high:2621, device_low:18, device_high:18
# time_low:2633, time_high:2633, device_low:4, device_high:4
# time_low:2633, time_high:2633, device_low:6, device_high:6
# time_low:2623, time_high:2623, device_low:14, device_high:14
# time_low:2646, time_high:2646, device_low:9, device_high:9
# time_low:2642, time_high:2642, device_low:5, device_high:5
# time_low:2653, time_high:2653, device_low:5, device_high:5
# time_low:2642, time_high:2642, device_low:4, device_high:4
# time_low:2644, time_high:2644, device_low:3, device_high:3
# time_low:2657, time_high:2657, device_low:4, device_high:4
# time_low:2657, time_high:2657, device_low:4, device_high:4
# time_low:2646, time_high:2646, device_low:13, device_high:13
# time_low:2655, time_high:2655, device_low:11, device_high:11
# time_low:2652, time_high:2652, device_low:12, device_high:12
# time_low:2662, time_high:2662, device_low:5, device_high:5
# time_low:2670, time_high:2670, device_low:1, device_high:1
# time_low:2665, time_high:2665, device_low:17, device_high:17
# time_low:2664, time_high:2664, device_low:19, device_high:19
# time_low:2660, time_high:2660, device_low:18, device_high:18
# time_low:2677, time_high:2677, device_low:16, device_high:16
# time_low:2678, time_high:2678, device_low:14, device_high:14
# time_low:2676, time_high:2676, device_low:16, device_high:16
# time_low:2662, time_high:2662, device_low:11, device_high:11
# time_low:2675, time_high:2675, device_low:8, device_high:8
# time_low:2695, time_high:2695, device_low:20, device_high:20
# time_low:2689, time_high:2689, device_low:20, device_high:20
# time_low:2681, time_high:2681, device_low:10, device_high:10
# time_low:2687, time_high:2687, device_low:3, device_high:3
# time_low:2681, time_high:2681, device_low:5, device_high:5
# time_low:2697, time_high:2697, device_low:17, device_high:17
# time_low:2692, time_high:2692, device_low:19, device_high:19
# time_low:2691, time_high:2691, device_low:3, device_high:3
# time_low:2682, time_high:2682, device_low:18, device_high:18
# time_low:2680, time_high:2680, device_low:10, device_high:10
# time_low:2701, time_high:2701, device_low:17, device_high:17
# time_low:2713, time_high:2713, device_low:20, device_high:20
# time_low:2711, time_high:2711, device_low:19, device_high:19
# time_low:2710, time_high:2710, device_low:9, device_high:9
# time_low:2714, time_high:2714, device_low:10, device_high:10
# time_low:2706, time_high:2706, device_low:1, device_high:1
# time_low:2703, time_high:2703, device_low:18, device_high:18
# time_low:2707, time_high:2707, device_low:16, device_high:16
# time_low:2707, time_high:2707, device_low:10, device_high:10
# time_low:2704, time_high:2704, device_low:6, device_high:6
# time_low:2735, time_high:2735, device_low:5, device_high:5
# time_low:2731, time_high:2731, device_low:20, device_high:20
# time_low:2730, time_high:2730, device_low:12, device_high:12
# time_low:2737, time_high:2737, device_low:20, device_high:20
# time_low:2733, time_high:2733, device_low:6, device_high:6
# time_low:2726, time_high:2726, device_low:3, device_high:3
# time_low:2739, time_high:2739, device_low:19, device_high:19
# time_low:2731, time_high:2731, device_low:2, device_high:2
# time_low:2722, time_high:2722, device_low:4, device_high:4
# time_low:2735, time_high:2735, device_low:7, device_high:7
# time_low:2740, time_high:2740, device_low:17, device_high:17
# time_low:2752, time_high:2752, device_low:9, device_high:9
# time_low:2744, time_high:2744, device_low:9, device_high:9
# time_low:2758, time_high:2758, device_low:13, device_high:13
# time_low:2751, time_high:2751, device_low:16, device_high:16
# time_low:2742, time_high:2742, device_low:12, device_high:12
# time_low:2740, time_high:2740, device_low:5, device_high:5
# time_low:2755, time_high:2755, device_low:13, device_high:13
# time_low:2740, time_high:2740, device_low:3, device_high:3
# time_low:2745, time_high:2745, device_low:2, device_high:2
# time_low:2766, time_high:2766, device_low:1, device_high:1
# time_low:2767, time_high:2767, device_low:20, device_high:20
# time_low:2774, time_high:2774, device_low:4, device_high:4
# time_low:2761, time_high:2761, device_low:6, device_high:6
# time_low:2777, time_high:2777, device_low:20, device_high:20
# time_low:2771, time_high:2771, device_low:5, device_high:5
# time_low:2778, time_high:2778, device_low:18, device_high:18
# time_low:2768, time_high:2768, device_low:10, device_high:10
# time_low:2761, time_high:2761, device_low:20, device_high:20
# time_low:2770, time_high:2770, device_low:11, device_high:11
# time_low:2782, time_high:2782, device_low:7, device_high:7
# time_low:2795, time_high:2795, device_low:17, device_high:17
# time_low:2785, time_high:2785, device_low:5, device_high:5
# time_low:2785, time_high:2785, device_low:20, device_high:20
# time_low:2791, time_high:2791, device_low:8, device_high:8
# time_low:2790, time_high:2790, device_low:20, device_high:20
# time_low:2788, time_high:2788, device_low:2, device_high:2
# time_low:2790, time_high:2790, device_low:4, device_high:4
# time_low:2790, time_high:2790, device_low:20, device_high:20
# time_low:2796, time_high:2796, device_low:9, device_high:9
# time_low:2808, time_high:2808, device_low:8, device_high:8
# time_low:2810, time_high:2810, device_low:8, device_high:8
# time_low:2818, time_high:2818, device_low:10, device_high:10
# time_low:2810, time_high:2810, device_low:14, device_high:14
# time_low:2806, time_high:2806, device_low:3, device_high:3
# time_low:2805, time_high:2805, device_low:3, device_high:3
# time_low:2810, time_high:2810, device_low:17, device_high:17
# time_low:2803, time_high:2803, device_low:20, device_high:20
# time_low:2805, time_high:2805, device_low:5, device_high:5
# time_low:2814, time_high:2814, device_low:14, device_high:14
# time_low:2837, time_high:2837, device_low:17, device_high:17
# time_low:2829, time_high:2829, device_low:1, device_high:1
# time_low:2824, time_high:2824, device_low:18, device_high:18
# time_low:2839, time_high:2839, device_low:9, device_high:9
# time_low:2823, time_high:2823, device_low:19, device_high:19
# time_low:2822, time_high:2822, device_low:7, device_high:7
# time_low:2831, time_high:2831, device_low:19, device_high:19
# time_low:2824, time_high:2824, device_low:17, device_high:17
# time_low:2839, time_high:2839, device_low:3, device_high:3
# time_low:2830, time_high:2830, device_low:9, device_high:9
# time_low:2847, time_high:2847, device_low:15, device_high:15
# time_low:2843, time_high:2843, device_low:8, device_high:8
# time_low:2845, time_high:2845, device_low:15, device_high:15
# time_low:2855, time_high:2855, device_low:5, device_high:5
# time_low:2858, time_high:2858, device_low:8, device_high:8
# time_low:2854, time_high:2854, device_low:7, device_high:7
# time_low:2849, time_high:2849, device_low:16, device_high:16
# time_low:2855, time_high:2855, device_low:19, device_high:19
# time_low:2850, time_high:2850, device_low:14, device_high:14
# time_low:2857, time_high:2857, device_low:15, device_high:15
# time_low:2863, time_high:2863, device_low:11, device_high:11
# time_low:2879, time_high:2879, device_low:17, device_high:17
# time_low:2875, time_high:2875, device_low:5, device_high:5
# time_low:2860, time_high:2860, device_low:2, device_high:2
# time_low:2879, time_high:2879, device_low:11, device_high:11
# time_low:2873, time_high:2873, device_low:18, device_high:18
# time_low:2879, time_high:2879, device_low:16, device_high:16
# time_low:2866, time_high:2866, device_low:17, device_high:17
# time_low:2870, time_high:2870, device_low:18, device_high:18
# time_low:2878, time_high:2878, device_low:20, device_high:20
# time_low:2897, time_high:2897, device_low:14, device_high:14
# time_low:2899, time_high:2899, device_low:14, device_high:14
# time_low:2895, time_high:2895, device_low:2, device_high:2
# time_low:2887, time_high:2887, device_low:17, device_high:17
# time_low:2887, time_high:2887, device_low:16, device_high:16
# time_low:2889, time_high:2889, device_low:6, device_high:6
# time_low:2896, time_high:2896, device_low:6, device_high:6
# time_low:2886, time_high:2886, device_low:3, device_high:3
# time_low:2886, time_high:2886, device_low:20, device_high:20
# time_low:2880, time_high:2880, device_low:11, device_high:11
# time_low:2911, time_high:2911, device_low:11, device_high:11
# time_low:2902, time_high:2902, device_low:9, device_high:9
# time_low:2906, time_high:2906, device_low:10, device_high:10
# time_low:2900, time_high:2900, device_low:1, device_high:1
# time_low:2910, time_high:2910, device_low:5, device_high:5
# time_low:2916, time_high:2916, device_low:11, device_high:11
# time_low:2912, time_high:2912, device_low:14, device_high:14
# time_low:2912, time_high:2912, device_low:6, device_high:6
# time_low:2913, time_high:2913, device_low:18, device_high:18
# time_low:2914, time_high:2914, device_low:5, device_high:5
# time_low:2920, time_high:2920, device_low:19, device_high:19
# time_low:2928, time_high:2928, device_low:16, device_high:16
# time_low:2926, time_high:2926, device_low:2, device_high:2
# time_low:2932, time_high:2932, device_low:19, device_high:19
# time_low:2928, time_high:2928, device_low:19, device_high:19
# time_low:2936, time_high:2936, device_low:4, device_high:4
# time_low:2933, time_high:2933, device_low:5, device_high:5
# time_low:2921, time_high:2921, device_low:12, device_high:12
# time_low:2934, time_high:2934, device_low:9, device_high:9
# time_low:2920, time_high:2920, device_low:6, device_high:6
# time_low:2956, time_high:2956, device_low:3, device_high:3
# time_low:2947, time_high:2947, device_low:18, device_high:18
# time_low:2956, time_high:2956, device_low:11, device_high:11
# time_low:2959, time_high:2959, device_low:4, device_high:4
# time_low:2947, time_high:2947, device_low:15, device_high:15
# time_low:2950, time_high:2950, device_low:5, device_high:5
# time_low:2941, time_high:2941, device_low:14, device_high:14
# time_low:2947, time_high:2947, device_low:14, device_high:14
# time_low:2945, time_high:2945, device_low:12, device_high:12
# time_low:2942, time_high:2942, device_low:20, device_high:20
# time_low:2976, time_high:2976, device_low:7, device_high:7
# time_low:2976, time_high:2976, device_low:2, device_high:2
# time_low:2977, time_high:2977, device_low:19, device_high:19
# time_low:2964, time_high:2964, device_low:4, device_high:4
# time_low:2961, time_high:2961, device_low:10, device_high:10
# time_low:2973, time_high:2973, device_low:5, device_high:5
# time_low:2976, time_high:2976, device_low:14, device_high:14
# time_low:2978, time_high:2978, device_low:10, device_high:10
# time_low:2960, time_high:2960, device_low:2, device_high:2
# time_low:2974, time_high:2974, device_low:5, device_high:5
# time_low:2983, time_high:2983, device_low:18, device_high:18
# time_low:2980, time_high:2980, device_low:18, device_high:18
# time_low:2994, time_high:2994, device_low:5, device_high:5
# time_low:2985, time_high:2985, device_low:5, device_high:5
# time_low:2989, time_high:2989, device_low:11, device_high:11
# time_low:2995, time_high:2995, device_low:1, device_high:1
# time_low:2983, time_high:2983, device_low:13, device_high:13
# time_low:2992, time_high:2992, device_low:13, device_high:13
# time_low:2980, time_high:2980, device_low:11, device_high:11
# time_low:2993, time_high:2993, device_low:9, device_high:9

# %%
for idx in range(len(found_in_basic_batch)):
    found_in_basic_batch[idx] = list(set(found_in_basic_batch[idx]))

# %%
for idx in range(len(found_in_proposed_batch)):
    found_in_proposed_batch[idx] = list(set(found_in_proposed_batch[idx]))

# %%
batches_sum = 0
for item in found_in_basic_batch:
    batches_sum += len(item)
print(f"basic 的 batch 数量{batches_sum}")
batches_sum = 0
for item in found_in_proposed_batch:
    batches_sum += len(item)
print(f"proposed 的 batch 数量{batches_sum}")
# Out:
# basic 的 batch 数量1500
# proposed 的 batch 数量1500

# %%
# 计算每个子列表中的元素数量
basic_counts = [len(sublist) for sublist in found_in_basic_batch]
proposed_counts = [len(sublist) for sublist in found_in_proposed_batch]

# 创建一个数字并设置其大小
plt.figure(figsize=(10, 6))

# 绘制箱线图
plt.boxplot([basic_counts, proposed_counts], labels=['Basic Batch', 'Ratio-Cut Batch'])

# 添加标题和标签
plt.title('Comparison of Batch Counts in Queries')
plt.ylabel('Batch Count')

# 显示图表
plt.show()

# %% [markdown]
# ##### 根据目前每个 Query 中的数据点所在的 Batch_id 到 store_node 中寻找存储了相应的 Batch_id 的 node， 得到 node_id， 再根据 node_id计算出访问失败次数与总计时间

# %%
# 现在已经找到了所有要访问的 Batch, 之后到store_node_method_r_d_batched_basic_method 和 store_node_method_r_d_batched_proposed_method 中寻找 存储了相应的 Batch 的 node
# 要访问的每个 batch 在哪个 store node 中, 并计算累计的 1. 访问无服务次数 2. 有服务时的访问时延
# 在Batch中 按照每5个Query为单位 存储了要访问的batch 有哪几个（会出现重复）

# found_in_basic_batch = []      # [[], [], ..., []]
# found_in_proposed_batch = []   # [[], [], ..., []]

# found_in_basic_node
found_in_basic_node_r_d = []
basic_node_tmp = []
for query in found_in_basic_batch:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_r_d_batched_basic_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    basic_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_basic_node_r_d.append(copy.deepcopy(basic_node_tmp))
    basic_node_tmp.clear()


# found_in_proposed_node
found_in_proposed_node_r_d = []
proposed_node_tmp = []
for query in found_in_proposed_batch:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_r_d_batched_proposed_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    proposed_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_proposed_node_r_d.append(copy.deepcopy(proposed_node_tmp))
    proposed_node_tmp.clear()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[156], line 44
#      42     break
#      43 for key, value in node_info['batches']:
# ---> 44     if int(batch_id) == int(key):
#      45         proposed_node_tmp.append(node_id)
#      46         flag = True
#
# KeyboardInterrupt:

# %%
for idx in range(len(found_in_basic_node_r_d)):
    found_in_basic_node_r_d[idx] = list(set(found_in_basic_node_r_d[idx]))
for idx in range(len(found_in_proposed_node_r_d)):
    found_in_proposed_node_r_d[idx] = list(set(found_in_proposed_node_r_d[idx]))

# %%
nodes_sum = 0
for item in found_in_basic_node_r_d:
    nodes_sum += len(item)
print(f"basic r_d 的 node 数量{nodes_sum}")
nodes_sum = 0
for item in found_in_proposed_node_r_d:
    nodes_sum += len(item)
print(f"proposed r_d 的 node 数量{nodes_sum}")

# %%
# 计算每个子列表中的元素数量
basic_counts = [len(sublist) for sublist in found_in_basic_node_r_d]
proposed_counts = [len(sublist) for sublist in found_in_proposed_node_r_d]

# 创建一个数字并设置其大小
plt.figure(figsize=(10, 6))

# 绘制箱线图
plt.boxplot([basic_counts, proposed_counts], labels=['Basic Node', 'Ratio-Cut Node'])

# 添加标题和标签
plt.title('Comparison of Batch Counts in Queries')
plt.ylabel('Node Count')

# 显示图表
plt.show()

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic = cal_time(found_in_basic_node_r_d, store_node_method_r_d_batched_basic_method)
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed = cal_time(found_in_proposed_node_r_d, store_node_method_r_d_batched_proposed_method)

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic

# %%
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed

# %% [markdown]
# # 方法二：有信誉无距离

# %%
# 根据Storage Space + Probability 计算出Score rank，随机在Rank 前10中取一个 node 存储
store_node_method_r = copy.deepcopy(store_node)

# %%
store_node_method_r_batched_basic_method = copy.deepcopy(store_node_method_r)

for key, batch in batched_basic_method.items():
    # 要选取一个store node存储
    sorted_nodes_r = sorted(store_node_method_r_batched_basic_method.items(), key=lambda x: x[1]['score_sp'], reverse=True) # Ture 指定为降序排序

    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes_r = sorted_nodes_r[:10]
    saved_flag = False
    for node in top_ten_nodes_r:
        if saved_flag:
            break
        get_pro = node[1]['probability']
        # 得到命中概率
        if probabilistic_true(get_pro):
            # 若命中，则存入
            store_node_method_r_batched_basic_method[node[0]]['batches'].append((key, batch))
            saved_flag = True
            
    if not saved_flag:
        # 10 个都没命中，则存入 rank 第一的 node 中
        store_node_method_r_batched_basic_method[top_ten_nodes_r[0][0]]['batches'].append((key, batch))

# %%
store_node_method_r_batched_proposed_method = copy.deepcopy(store_node_method_r)

for key, batch in batched_proposed_method.items():
    # 要选取一个store node存储
    sorted_nodes_r = sorted(store_node_method_r_batched_proposed_method.items(), key=lambda x: x[1]['score_sp'], reverse=True)
    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes_r = sorted_nodes_r[:10]
    saved_flag = False
    for node in top_ten_nodes_r:
        if saved_flag:
            break
        get_pro = node[1]['probability']
        # 得到命中概率
        if probabilistic_true(get_pro):
            # 若命中，则存入
            store_node_method_r_batched_proposed_method[node[0]]['batches'].append((key, batch))
            saved_flag = True
    if not saved_flag:
        # 10 个都没命中，则存入 rank 第一的 node 中
        store_node_method_r_batched_proposed_method[top_ten_nodes_r[0][0]]['batches'].append((key, batch))

# %%
# 遍历Query_sets，在两种store node的存储方式上，访问所有的query，计算得到指标
found_in_basic_batch_r = [] # [[], [], ..., []] 记录了每个 query 中每个 point 所在的batch_id ， 用于后续去 store
found_in_proposed_batch_r = []
for query_set in Query_sets:
    basic_batches4q = []
    proposed_batches4q = []
    for query in query_set:
        # 对每一个 q, 得到 time 和 device 
        time_low, time_high, device_low, device_high = query[0][0], query[0][1], query[1][0], query[1][1]
        print(f"time_low:{time_low}, time_high:{time_high}, device_low:{device_low}, device_high:{device_high}")
        # 找到 device 所在的 batch, 计算出每个 q 需要访问哪些 batch
        # 直接遍历搜索空间过大，进行优化: 从time来确定Batch_id范围: 0~19s 内的数据处于 0~3 的 batch 之间
        # 由于 同一批Query_set中的元素都在同一批Batch中，故直接由time_low定出 batch range
        batch_low, batch_high = int(time_low / time_on_chain) * int(time_on_chain * device_value_max / unit_num / batch_num), (int(time_low / time_on_chain) + 1) * int(time_on_chain * device_value_max / unit_num / batch_num) - 1
        # print(f"batch_low:{batch_low} and batch_high:{batch_high}")
        for device in range(device_low, device_high + 1):
            for time in range(time_low, time_high + 1):
                # print(f"time: {time}, device: {device}")
                basic_flag = False
                proposed_flag = False
                # 对每个 （time, device） 找到所属的Batch
                for batch_id in range(batch_low, batch_high + 1):
                    # print(f"batch id is : {batch}")
                    # batch结构: [[], [], ..., []]
                    if not basic_flag:
                        batch = copy.deepcopy(batched_basic_method[str(batch_id)])
                        for unit in batch:
                            for point in unit:
                                # print(f"{point[0]}  and  {point[1]}")
                                if time == point[0] and device == point[1]:
                                    # print(f"----basic find point")
                                    # 找到了所属的Batch，继续寻找所属的store node
                                    basic_batches4q.append(batch_id)
                                    basic_flag = True
                    if not proposed_flag:
                        batch = copy.deepcopy(batched_proposed_method[str(batch_id)])
                        for unit in batch:
                            if time == unit[0] and device == unit[1]:
                                # print(f"----proposed find point")
                                # 找到了所属的Batch，继续寻找所属的store node
                                proposed_batches4q.append(batch_id)
                                proposed_flag = True
                    if proposed_flag and basic_flag:
                        break
                # print(f"belong_to_basic_batch:{belong_to_basic_batch} and belong_to_proposed_batch:{belong_to_proposed_batch}")
        found_in_basic_batch_r.append(copy.deepcopy(basic_batches4q))
        found_in_proposed_batch_r.append(copy.deepcopy(proposed_batches4q))
        basic_batches4q.clear()
        proposed_batches4q.clear()

# %%
for idx in range(len(found_in_basic_batch_r)):
    found_in_basic_batch_r[idx] = list(set(found_in_basic_batch_r[idx]))

# %%
for idx in range(len(found_in_proposed_batch_r)):
    found_in_proposed_batch_r[idx] = list(set(found_in_proposed_batch_r[idx]))

# %%
batches_sum = 0
for item in found_in_basic_batch_r:
    batches_sum += len(item)
print(f"basic r 的 batch 数量{batches_sum}")
batches_sum = 0
for item in found_in_proposed_batch_r:
    batches_sum += len(item)
print(f"proposed r 的 batch 数量{batches_sum}")

# %%
found_in_basic_node_r = []
basic_node_tmp = []
for query in found_in_basic_batch_r:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_r_batched_basic_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    basic_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_basic_node_r.append(copy.deepcopy(basic_node_tmp))
    basic_node_tmp.clear()

# found_in_proposed_node
found_in_proposed_node_r = []
proposed_node_tmp = []
for query in found_in_proposed_batch:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_r_batched_proposed_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    proposed_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_proposed_node_r.append(copy.deepcopy(proposed_node_tmp))
    proposed_node_tmp.clear()

# %%
for idx in range(len(found_in_basic_node_r)):
    found_in_basic_node_r[idx] = list(set(found_in_basic_node_r[idx]))

# %%
for idx in range(len(found_in_proposed_node_r)):
    found_in_proposed_node_r[idx] = list(set(found_in_proposed_node_r[idx]))

# %%
nodes_sum = 0
for item in found_in_basic_node_r:
    nodes_sum += len(item)
print(f"basic r 的 node 数量{nodes_sum}")
nodes_sum = 0
for item in found_in_proposed_node_r:
    nodes_sum += len(item)
print(f"proposed r 的 node 数量{nodes_sum}")

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic = cal_time(found_in_basic_node_r, store_node_method_r_batched_basic_method)
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed = cal_time(found_in_proposed_node_r, store_node_method_r_batched_proposed_method)

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic

# %%
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed

# %% [markdown]
# # 方法三：无信誉有距离

# %%
# 根据Storage Space + Distance 计算出Score rank，随机在Rank 前10中取一个 node 存储
store_node_method_d = copy.deepcopy(store_node)

# %%
# batched_basic_method 
store_node_method_d_batched_basic_method = copy.deepcopy(store_node_method_d)

for key, batch in batched_basic_method.items():
    # 要选取一个store node存储
    sorted_nodes_d = sorted(store_node_method_d_batched_basic_method.items(), key=lambda x: x[1]['score_sd'], reverse=False) # 升序排序，距离越小越优先
    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes = sorted_nodes_d[:10]
    random_choice_node= random.choice(top_ten_nodes)
    store_node_method_d_batched_basic_method[random_choice_node[0]]['batches'].append((key, batch))

# %%
store_node_method_d_batched_proposed_method = copy.deepcopy(store_node_method_d)

for key, batch in batched_proposed_method.items():
    # 要选取一个store node存储
    sorted_nodes_d = sorted(store_node_method_d_batched_proposed_method.items(), key=lambda x: x[1]['score_sd'], reverse=False) # 升序排序，距离越小越优先
    # 从得分前 10 的节点中随机选择一个节点
    top_ten_nodes = sorted_nodes_d[:10]
    random_choice_node = random.choice(top_ten_nodes)
    store_node_method_d_batched_proposed_method[random_choice_node[0]]['batches'].append((key, batch))

# %%
# 遍历Query_sets，在两种store node的存储方式上，访问所有的query，计算得到指标
found_in_basic_batch = [] # [[], [], ..., []] 记录了每个 query 中每个 point 所在的batch_id ， 用于后续去 store
found_in_proposed_batch = []
found_in_basic_batch.clear()
found_in_proposed_batch.clear()
for query_set in Query_sets:
    basic_batches4q = []
    proposed_batches4q = []
    for query in query_set:
        # 对每一个 q, 得到 time 和 device 
        time_low, time_high, device_low, device_high = query[0][0], query[0][1], query[1][0], query[1][1]
        print(f"time_low:{time_low}, time_high:{time_high}, device_low:{device_low}, device_high:{device_high}")
        # 找到 device 所在的 batch, 计算出每个 q 需要访问哪些 batch
        # 直接遍历搜索空间过大，进行优化: 从time来确定Batch_id范围: 0~19s 内的数据处于 0~3 的 batch 之间
        # 由于 同一批Query_set中的元素都在同一批Batch中，故直接由time_low定出 batch range
        batch_low, batch_high = int(time_low / time_on_chain) * int(time_on_chain * device_value_max / unit_num / batch_num), (int(time_low / time_on_chain) + 1) * int(time_on_chain * device_value_max / unit_num / batch_num) - 1
        # print(f"batch_low:{batch_low} and batch_high:{batch_high}")
        for device in range(device_low, device_high + 1):
            for time in range(time_low, time_high + 1):
                # print(f"time: {time}, device: {device}")
                basic_flag = False
                proposed_flag = False
                # 对每个 （time, device） 找到所属的Batch
                for batch_id in range(batch_low, batch_high + 1):
                    # print(f"batch id is : {batch}")
                    # batch结构: [[], [], ..., []]
                    
                    if not basic_flag:
                        batch = copy.deepcopy(batched_basic_method[str(batch_id)])
                        for unit in batch:
                            for point in unit:
                                # print(f"{point[0]}  and  {point[1]}")
                                if time == point[0] and device == point[1]:
                                    # print(f"----basic find point")
                                    # 找到了所属的Batch，继续寻找所属的store node
                                    basic_batches4q.append(batch_id)
                                    basic_flag = True
                                
                    if not proposed_flag:
                        batch = copy.deepcopy(batched_proposed_method[str(batch_id)])
                        for unit in batch:
                            if time == unit[0] and device == unit[1]:
                                # print(f"----proposed find point")
                                # 找到了所属的Batch，继续寻找所属的store node
                                proposed_batches4q.append(batch_id)
                                proposed_flag = True
                    if proposed_flag and basic_flag:
                        break
                # print(f"belong_to_basic_batch:{belong_to_basic_batch} and belong_to_proposed_batch:{belong_to_proposed_batch}")
        found_in_basic_batch.append(copy.deepcopy(basic_batches4q))
        found_in_proposed_batch.append(copy.deepcopy(proposed_batches4q))
        basic_batches4q.clear()
        proposed_batches4q.clear()

# %%
for idx in range(len(found_in_basic_batch)):
    found_in_basic_batch[idx] = list(set(found_in_basic_batch[idx]))
for idx in range(len(found_in_proposed_batch)):
    found_in_proposed_batch[idx] = list(set(found_in_proposed_batch[idx]))

# %%
batches_sum = 0
for item in found_in_basic_batch:
    batches_sum += len(item)
print(f"basic d 的 batch 数量{batches_sum}")
batches_sum = 0
for item in found_in_proposed_batch:
    batches_sum += len(item)
print(f"proposed d 的 batch 数量{batches_sum}")

# %%
found_in_basic_node_d = []
basic_node_tmp = []
for query in found_in_basic_batch:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_d_batched_basic_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    basic_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_basic_node_d.append(copy.deepcopy(basic_node_tmp))
    basic_node_tmp.clear()


# found_in_proposed_node
found_in_proposed_node_d = []
proposed_node_tmp = []
for query in found_in_proposed_batch:
    # print(query)
    found_batches = list(set(query))
    # print(found_batches)
    for batch_id in found_batches:
        # 首先要合并所有相同的 batch_id , 再对每个不同的Batch_id到store_node中找到 node_id 存入found_in_xxx_node
        flag = False
        for node_id, node_info in store_node_method_d_batched_proposed_method.items():
            if flag:
                break            
            for key, value in node_info['batches']:
                if int(batch_id) == int(key):
                    proposed_node_tmp.append(node_id)
                    flag = True
                    break
    found_in_proposed_node_d.append(copy.deepcopy(proposed_node_tmp))
    proposed_node_tmp.clear()

# %%
for idx in range(len(found_in_basic_node_d)):
    found_in_basic_node_d[idx] = list(set(found_in_basic_node_d[idx]))
for idx in range(len(found_in_proposed_node_d)):
    found_in_proposed_node_d[idx] = list(set(found_in_proposed_node_d[idx]))

# %%
nodes_sum = 0
for item in found_in_basic_node_d:
    nodes_sum += len(item)
print(f"basic r 的 node 数量{nodes_sum}")
nodes_sum = 0
for item in found_in_proposed_node_d:
    nodes_sum += len(item)
print(f"proposed r 的 node 数量{nodes_sum}")

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic = cal_time(found_in_basic_node_d, store_node_method_d_batched_basic_method)
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed = cal_time(found_in_proposed_node_d, store_node_method_d_batched_proposed_method)

# %%
time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic

# %%
time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed

# %%
time_consumed_max_basic_r_d, refuse_cnt_basic_r_d, accept_cnt_basic_r_d, serve_prob_basic_r_d = cal_time(found_in_basic_node_r_d, store_node_method_r_batched_basic_method)
time_consumed_max_proposed_r_d, refuse_cnt_proposed_r_d, accept_cnt_proposed_r_d, serve_prob_proposed_r_d = cal_time(found_in_proposed_node_r_d, store_node_method_r_batched_proposed_method)

time_consumed_max_basic_r, refuse_cnt_basic_r, accept_cnt_basic_r, serve_prob_basic_r = cal_time(found_in_basic_node_r, store_node_method_r_batched_basic_method)
time_consumed_max_proposed_r, refuse_cnt_proposed_r, accept_cnt_proposed_r, serve_prob_proposed_r = cal_time(found_in_proposed_node_r, store_node_method_r_batched_proposed_method)

time_consumed_max_basic_d, refuse_cnt_basic_d, accept_cnt_basic_d, serve_prob_basic_d = cal_time(found_in_basic_node_d, store_node_method_d_batched_basic_method)
time_consumed_max_proposed_d, refuse_cnt_proposed_d, accept_cnt_proposed_d, serve_prob_proposed_d = cal_time(found_in_proposed_node_d, store_node_method_d_batched_proposed_method)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Sample data based on the user's descriptions
# Data is assumed for demonstration as actual data isn't provided
data_basic_r_d = [time_consumed_max_basic_r_d, refuse_cnt_basic_r_d, accept_cnt_basic_r_d, serve_prob_basic_r_d]  # time_consumed_max_basic_r_d, refuse_cnt_basic_r_d, accept_cnt_basic_r_d, serve_prob_basic_r_d
data_proposed_r_d = [time_consumed_max_proposed_r_d, refuse_cnt_proposed_r_d, accept_cnt_proposed_r_d, serve_prob_proposed_r_d]  # time_consumed_max_proposed_r_d, refuse_cnt_proposed_r_d, accept_cnt_proposed_r_d, serve_prob_proposed_r_d

data_basic_r = [time_consumed_max_basic_r, refuse_cnt_basic_r, accept_cnt_basic_r, serve_prob_basic_r]  # time_consumed_max_basic_r, refuse_cnt_basic_r, accept_cnt_basic_r, serve_prob_basic_r
data_proposed_r = [time_consumed_max_proposed_r, refuse_cnt_proposed_r, accept_cnt_proposed_r, serve_prob_proposed_r]  # time_consumed_max_proposed_r, refuse_cnt_proposed_r, accept_cnt_proposed_r, serve_prob_proposed_r

data_basic_d = [time_consumed_max_basic_d, refuse_cnt_basic_d, accept_cnt_basic_d, serve_prob_basic_d]  # time_consumed_max_basic, refuse_cnt_basic, accept_cnt_basic, serve_prob_basic
data_proposed_d = [time_consumed_max_proposed_d, refuse_cnt_proposed_d, accept_cnt_proposed_d, serve_prob_proposed_d]  # time_consumed_max_proposed, refuse_cnt_proposed, accept_cnt_proposed, serve_prob_proposed

categories = ['Propagation delay', 'refuse_cnt', 'accept_cnt', 'Access Probability']

# Plot 1: Horizontal comparison for basic method
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(categories))

# Plot bars for time_consumed_max, refuse_cnt, accept_cnt, and serve_prob with primary y-axis for the first three metrics
ax1.bar(index, data_basic_r_d, bar_width, label='Reputation & Distance')
ax1.bar(index + bar_width, data_basic_r, bar_width, label='Reputation')
ax1.bar(index + 2 * bar_width, data_basic_d, bar_width, label='Distance')

# Set labels, title, and legend for primary axis
ax1.set_xlabel('Metrics')
ax1.set_ylabel('Values')
ax1.set_title('Comparison of 3 consensus Results(Basic Batch Method query*800)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(categories)
ax1.legend(loc='upper left')

# Create secondary axis for serve_prob with adjusted range
ax2 = ax1.twinx()
ax2.set_ylabel('Access Probability')

# Adjust the range of serve_prob to be more prominent
serve_prob_scaled_r_d = np.array(data_basic_r_d[-1]) # Scaling factor
serve_prob_scaled_r = np.array(data_basic_r[-1])
serve_prob_scaled_d = np.array(data_basic_d[-1])

# Plot scaled serve_prob values as bars on secondary axis
ax2.bar(index[-1], serve_prob_scaled_r_d, bar_width, label='Access Probability reputation & distance', alpha=0.7)
ax2.bar(index[-1] + bar_width, serve_prob_scaled_r, bar_width, label='Access Probability reputation', alpha=0.7)
ax2.bar(index[-1] + 2 * bar_width, serve_prob_scaled_d, bar_width, label='Access Probability distance', alpha=0.7)

ax2.set_ylim(0, 1)  # Adjust the range of secondary axis for serve_prob

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

plt.show()

# %%
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(categories))

# Plot bars for time_consumed_max, refuse_cnt, accept_cnt, and serve_prob with primary y-axis for the first three metrics
ax1.bar(index, data_proposed_r_d, bar_width, label='Reputation & Distance')
ax1.bar(index + bar_width, data_proposed_r, bar_width, label='Reputation')
ax1.bar(index + 2 * bar_width, data_proposed_d, bar_width, label='Distance')

# Set labels, title, and legend for primary axis
ax1.set_xlabel('Metrics')
ax1.set_ylabel('Values')
ax1.set_title('Comparison of 3 consensus Results(RatioCut Batch Method query*800)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(categories)
ax1.legend(loc='upper left')

# Create secondary axis for serve_prob with adjusted range
ax2 = ax1.twinx()
ax2.set_ylabel('Access Probability')

# Adjust the range of serve_prob to be more prominent
serve_prob_scaled_r_d = np.array(data_proposed_r_d[-1]) # Scaling factor
serve_prob_scaled_r = np.array(data_proposed_r[-1])
serve_prob_scaled_d = np.array(data_proposed_d[-1])

# Plot scaled serve_prob values as bars on secondary axis
ax2.bar(index[-1], serve_prob_scaled_r_d, bar_width, label='Access Probability Reputation & Distance', alpha=0.7)
ax2.bar(index[-1] + bar_width, serve_prob_scaled_r, bar_width, label='Access Probability Reputation', alpha=0.7)
ax2.bar(index[-1] + 2 * bar_width, serve_prob_scaled_d, bar_width, label='Access Probability Distance', alpha=0.7)

ax2.set_ylim(0, 1)  # Adjust the range of secondary axis for serve_prob

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

plt.show()
# 修改颜色信息，并将prob调整到0.5-1之间，即增大全重

# %%
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(categories))

# Plot bars for time_consumed_max, refuse_cnt, accept_cnt, and serve_prob with primary y-axis for the first three metrics
ax1.bar(index, data_basic_r_d, bar_width, label='Propagation Delay(Basic)')
ax1.bar(index + bar_width, data_proposed_r_d, bar_width, label='Propagation Delay(RatioCut)')

# Set labels, title, and legend for primary axis
ax1.set_xlabel('Metrics')
ax1.set_ylabel('Values')
ax1.set_title('Comparison of Batch Method Results (Reputation & Distance)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(categories)
ax1.legend(loc='upper left')

# Create secondary axis for serve_prob with adjusted range
ax2 = ax1.twinx()
ax2.set_ylabel('Access Probability')

# Adjust the range of serve_prob to be more prominent
serve_prob_scaled_r_d_basic = np.array(data_basic_r_d[-1]) # Scaling factor
serve_prob_scaled_r_d_proposed = np.array(data_proposed_r_d[-1])

# Plot scaled serve_prob values as bars on secondary axis
ax2.bar(index[-1], serve_prob_scaled_r_d_basic, bar_width, label='Access Probability(Basic)', alpha=0.5)
ax2.bar(index[-1] + bar_width, serve_prob_scaled_r_d_proposed, bar_width, label='Access Probability(RatioCut)', alpha=0.5)

ax2.set_ylim(0, 1)  # Adjust the range of secondary axis for serve_prob

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

plt.show()

# %%
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(categories))

# Plot bars for time_consumed_max, refuse_cnt, accept_cnt, and serve_prob with primary y-axis for the first three metrics
ax1.bar(index, data_basic_r, bar_width, label='Propagation Delay(Basic)')
ax1.bar(index + bar_width, data_proposed_r, bar_width, label='Propagation Delay(RatioCut)')

# Set labels, title, and legend for primary axis
ax1.set_xlabel('Metrics')
ax1.set_ylabel('Values')
ax1.set_title('Comparison of Batch Method Results (Reputation)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(categories)
ax1.legend(loc='upper left')

# Create secondary axis for serve_prob with adjusted range
ax2 = ax1.twinx()
ax2.set_ylabel('Access Probability')

# Adjust the range of serve_prob to be more prominent
serve_prob_scaled_r_basic = np.array(data_basic_r[-1]) # Scaling factor
serve_prob_scaled_r_proposed = np.array(data_proposed_r[-1])

# Plot scaled serve_prob values as bars on secondary axis
ax2.bar(index[-1], serve_prob_scaled_r_basic, bar_width, label='Access Probability(Basic)', alpha=0.7)
ax2.bar(index[-1] + bar_width, serve_prob_scaled_r_proposed, bar_width, label='Access Probability(RatioCut)', alpha=0.7)

ax2.set_ylim(0, 1)  # Adjust the range of secondary axis for serve_prob

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

plt.show()

# %%
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = np.arange(len(categories))

# Plot bars for time_consumed_max, refuse_cnt, accept_cnt, and serve_prob with primary y-axis for the first three metrics
ax1.bar(index, data_basic_d, bar_width, label='Propagation Delay(Basic)')
ax1.bar(index + bar_width, data_proposed_d, bar_width, label='Propagation Delay(RatioCut)')

# Set labels, title, and legend for primary axis
ax1.set_xlabel('Metrics')
ax1.set_ylabel('Values')
ax1.set_title('Comparison of Batch Method Results (Distance)')
ax1.set_xticks(index + bar_width)
ax1.set_xticklabels(categories)
ax1.legend(loc='upper left')

# Create secondary axis for serve_prob with adjusted range
ax2 = ax1.twinx()
ax2.set_ylabel('Access Probability')

# Adjust the range of serve_prob to be more prominent
serve_prob_scaled_d_basic = np.array(data_basic_d[-1]) # Scaling factor
serve_prob_scaled_d_proposed = np.array(data_proposed_d[-1])

# Plot scaled serve_prob values as bars on secondary axis
ax2.bar(index[-1], serve_prob_scaled_d_basic, bar_width, label='Access Probability(Basic)', alpha=0.3)
ax2.bar(index[-1] + bar_width, serve_prob_scaled_d_proposed, bar_width, label='Access Probability(RatioCut)', alpha=0.3)

ax2.set_ylim(0, 1)  # Adjust the range of secondary axis for serve_prob

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

plt.show()
